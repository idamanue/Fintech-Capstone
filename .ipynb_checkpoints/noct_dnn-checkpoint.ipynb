# %%
import json
import pandas as pd
import numpy as np
import seaborn as sns
from datetime import datetime
import hvplot.pandas
from pathlib import Path
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import ElasticNet, Lasso, Ridge
from statsmodels.formula.api import ols
from sklearn import metrics
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.stats.anova import anova_lm
import matplotlib.pyplot as plt  # To visualize
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, cross_val_score

# %%
# Deep Learning libraries
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from sklearn.metrics import r2_score
from keras.optimizers import Adam
import keras
from keras.callbacks import EarlyStopping
import pandas as pd 
from sklearn.preprocessing import LabelEncoder 

from tensorflow import keras
import keras_tuner as kt

# %%
# Declaring global variables
RQUARE_CUTOFF = 0.7 # Min R-square value set to 75%
SIGMA = 2  # Number of standard deviation. 2-sigma

# %%
# Read CSv file and Return dataframe given module ID from the user
def get_csv(user_input):
    pathname = "Data/test_samples/" + user_input + ".csv"
    df = pd.read_csv(Path(pathname), header=1, usecols = ['TIMESTAMP', 'AirTemp_Avg', 'Irradiance_Pyr_NOCT_Avg', 'Wind_speed', 'Wind_direction', 'NOCT_Mod1_Cent1_Avg', 'NOCT_Mod1_Cent2_Avg'])
    #df = pd.read_csv(Path(pathname))

    return df

# %%
# Function that takes a directory pathname and returns the list of csv files in that directory
def get_csvfiles(pathname):
    dir_path = Path(pathname)
    csvfile = []
    p = dir_path.glob('*.csv')
    files = [x for x in p if x.is_file()]
    for f in files:
        for part in f.parts:
            if not part.startswith('.') and part.endswith('.csv'):
                csvfile.append(part)
    return csvfile

# %%
# This function takes the absolute or relative pathname to the data directory,
# Then create and return a list of dataframes
def get_dataframes(dir_pathname):
    dataframes = []
    csv_filenames = get_csvfiles(dir_pathname)
    for file in csv_filenames:
        table_name = file.split('.')[0]
        df = pd.read_csv(Path(dir_pathname + file), header=1, usecols = ['TIMESTAMP', 'AirTemp_Avg', 'Irradiance_Pyr_NOCT_Avg', 'Wind_speed', 'Wind_direction', 'NOCT_Mod1_Cent1_Avg', 'NOCT_Mod1_Cent2_Avg'])
        #df = pd.read_csv(Path(dir_pathname + file))
        dataframes.append(df)
    return dataframes

# %%
# This function takes a dataframe and split into a list of dataframes to obtain daily data

def split_df(df):
    df_lst = []  # declare the list to return
    df['date'] = df['date'].astype(str)  # convert date column to string
    dates = df['date'].unique().tolist() # store unique dates into a list
    for Date in dates:
        df_lst.append(df.loc[df['date'].str.contains(Date)])   # create and append df of rows that contain the date string
        
    return df_lst

# %%
# user define function
def model_builder(hp):
        
    # first layer of the model
    model = keras.Sequential([tf.keras.layers.InputLayer(input_shape=4,)])
    # specifying the min and max nodes for hidden layer
    hp_units = hp.Int('units', min_value=10, max_value=100)
    model.add(keras.layers.Dense(units=hp_units, activation='relu'))
    
    # output layer
    model.add(keras.layers.Dense(1, activation="linear"))
    #compiling the model
    model.compile(optimizer=keras.optimizers.SGD(),
                    loss='mean_squared_error')
    return model

# %%
# Create model
def create_model():
    model = Sequential()
    model.add(Dense(64, activation="relu", input_dim=4))
    model.add(Dense(16, activation="relu"))
    model.add(Dense(4, activation="relu"))
    
    # Since the regression is performed, a Dense layer containing a single neuron with a linear activation function.
    # Typically ReLu-based activation are used but since it performs regression, it needs a linear activation.
    model.add(Dense(1, activation="linear"))
    
    # Compile model: The model is initialized with the Adam optimizer and then it is compiled.
    model.compile(loss='mean_squared_error', optimizer=Adam(lr=1e-3, decay=1e-3 / 200))
    
    return model

# %%
# Train the model
def fit_model(model, monitor, epoch):
    # Patient early stopping
    es = EarlyStopping(monitor=monitor, mode='min', verbose=1, patience=200)
    
    # Fit the model
    history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=epoch, batch_size=100, verbose=2, callbacks=[es])
    
    return history

# %%
# Saving the model
def saving_model(model, filename):
    # Save a model using the HDF5 format
    model.save(filename)

# %%
# Saving history
def saving_history(history, filepath):
    # Get the dictionary containing each metric and the loss for each epoch
    history_dict = history.history
    # Save it under the form of a json file
    json.dump(history_dict, open(filepath, 'w'))

# %%
# Load a model from the HDF5 format
def loading_model(filename):
    loaded_h5_model = tf.keras.models.load_model(filename)
    
    return loaded_h5_model

# %%
# Load history from the json format
def loading_history(filename):
    history_dict = json.load(open(filename, 'r'))
    
    return history_dict

# %%
# Calculate predictions
def calculate_predictions(model):
    predictions = {}
    predictions['train'] = model.predict(X_train)
    predictions['test'] = model.predict(X_test)
    
    return predictions

# %%
# Plot training history
def plot_training(history_dict, filepath):
    plt.plot(history_dict['loss'], label='train')
    plt.plot(history_dict['val_loss'], label='test')
    plt.legend()
    plt.savefig(filepath)

# %%
# Plot actual vs prediction
def actual_prediction_plot(y, prediction_set, title, filepath):
    plt.plot(y,prediction_set,'ro')
    plt.title(title)
    plt.xlabel('Actual')
    plt.ylabel('Predicted')
    plt.savefig(filepath)

# %%
# Compute scores value for a set
def compute_metrics(y, prediction_set):
    scores = []
    scores.append(metrics.r2_score(y,prediction_set))
    scores.append(metrics.mean_squared_error(y,prediction_set))
    
    return scores

# %%
# Compute NOCT value
def compute_noct(model):
    x = pd.DataFrame(columns=['irradiance', 'wind_speed', 'wind_direction', 'ambient_temperature'])
    x.loc[0] = [800,1,120,20]
    x = np.asarray(x)
    x=tf.convert_to_tensor(x, dtype=tf.int32)
    y_pred = model.predict(x)
    noct = float("{:.2f}".format( y_pred[0][0] ))
    
    return noct

# %%
'''
directory_pathname = "Data/Control_Module/"
dataframes = get_dataframes(directory_pathname)
combined_data = pd.concat(dataframes, axis=0, join='inner')
combined_data
'''

user_input = "QCL0201"
plotpath = 'plots/dnn_noct_' + user_input
combined_data = get_csv(user_input)
combined_data
# Out:
#                 TIMESTAMP AirTemp_Avg Wind_speed Wind_direction  \
# 0                      TS         NaN        NaN            Deg
# 1                     NaN         Avg        WVc            WVc
# 2                     NaN         NaN        NaN            NaN
# 3        6/6/2020 8:45:20        26.6       1.71            148
# 4        6/6/2020 8:45:25        26.6       1.45            125
# ...                   ...         ...        ...            ...
# 30993  6/23/2020 16:11:40        42.4       1.72            203
# 30994  6/23/2020 16:11:45        42.4       1.24            210
# 30995  6/23/2020 16:11:50        42.4       0.75            231
# 30996  6/23/2020 16:12:20        42.4       0.97            296
# 30997  6/23/2020 16:13:05        42.3       1.65            311
#
#       Irradiance_Pyr_NOCT_Avg NOCT_Mod1_Cent1_Avg NOCT_Mod1_Cent2_Avg
# 0                         NaN               Deg C               Deg C
# 1                         Avg                 Avg                 Avg
# 2                         NaN                 NaN                 NaN
# 3                    400.1855               41.82               41.84
# 4                    400.6653               41.89               41.83
# ...                       ...                 ...                 ...
# 30993                405.5959               56.25               56.07
# 30994                405.5959               56.28               55.96
# 30995                405.0982               56.17               55.89
# 30996                403.6052               55.82               55.33
# 30997                400.6175               55.79               55.22
#
# [30998 rows x 7 columns]

# %%
# Drop rows.
# Could also use labels: noct_csv.drop(labels=[0,1], axis=0)
combined_data.drop(combined_data.index[[0,1]], axis=0, inplace=True)
combined_data
# Out:
#                 TIMESTAMP AirTemp_Avg Wind_speed Wind_direction  \
# 2                     NaN         NaN        NaN            NaN
# 3        6/6/2020 8:45:20        26.6       1.71            148
# 4        6/6/2020 8:45:25        26.6       1.45            125
# 5        6/6/2020 8:46:20        26.8       1.42            114
# 6        6/6/2020 8:46:25        26.8       1.01             21
# ...                   ...         ...        ...            ...
# 30993  6/23/2020 16:11:40        42.4       1.72            203
# 30994  6/23/2020 16:11:45        42.4       1.24            210
# 30995  6/23/2020 16:11:50        42.4       0.75            231
# 30996  6/23/2020 16:12:20        42.4       0.97            296
# 30997  6/23/2020 16:13:05        42.3       1.65            311
#
#       Irradiance_Pyr_NOCT_Avg NOCT_Mod1_Cent1_Avg NOCT_Mod1_Cent2_Avg
# 2                         NaN                 NaN                 NaN
# 3                    400.1855               41.82               41.84
# 4                    400.6653               41.89               41.83
# 5                    404.0242               42.02               41.78
# 6                    404.0242               41.95               41.71
# ...                       ...                 ...                 ...
# 30993                405.5959               56.25               56.07
# 30994                405.5959               56.28               55.96
# 30995                405.0982               56.17               55.89
# 30996                403.6052               55.82               55.33
# 30997                400.6175               55.79               55.22
#
# [30996 rows x 7 columns]

# %%
# Change "NAN" values to NaN so they can be dropped
combined_data.replace("NAN", np.NaN, inplace=True)

# %%
# Drop the previous index and reset 
combined_data.reset_index(drop=True, inplace=True)
combined_data.head()
# Out:
#           TIMESTAMP AirTemp_Avg Wind_speed Wind_direction  \
# 0               NaN         NaN        NaN            NaN
# 1  6/6/2020 8:45:20        26.6       1.71            148
# 2  6/6/2020 8:45:25        26.6       1.45            125
# 3  6/6/2020 8:46:20        26.8       1.42            114
# 4  6/6/2020 8:46:25        26.8       1.01             21
#
#   Irradiance_Pyr_NOCT_Avg NOCT_Mod1_Cent1_Avg NOCT_Mod1_Cent2_Avg
# 0                     NaN                 NaN                 NaN
# 1                400.1855               41.82               41.84
# 2                400.6653               41.89               41.83
# 3                404.0242               42.02               41.78
# 4                404.0242               41.95               41.71

# %%
# Check data types
combined_data.dtypes
# Out:
# TIMESTAMP                  object
# AirTemp_Avg                object
# Wind_speed                 object
# Wind_direction             object
# Irradiance_Pyr_NOCT_Avg    object
# NOCT_Mod1_Cent1_Avg        object
# NOCT_Mod1_Cent2_Avg        object
# dtype: object

# %%
# Convert numeric columns to float
data = ['AirTemp_Avg', 'Irradiance_Pyr_NOCT_Avg', 'Wind_speed', 'Wind_direction', 'NOCT_Mod1_Cent1_Avg', 'NOCT_Mod1_Cent2_Avg']
for col in data:
    combined_data[col] = combined_data[col].astype('float')
combined_data.dtypes
# Out:
# TIMESTAMP                   object
# AirTemp_Avg                float64
# Wind_speed                 float64
# Wind_direction             float64
# Irradiance_Pyr_NOCT_Avg    float64
# NOCT_Mod1_Cent1_Avg        float64
# NOCT_Mod1_Cent2_Avg        float64
# dtype: object

# %%
# Delete all data outside the range 0.25 < wind speed < 1.75
indexWS = combined_data[ (combined_data['Wind_speed']<0.25) | (combined_data['Wind_speed']>1.75) ].index  # get index of the desired rows to drop
combined_data.drop(indexWS, axis=0, inplace=True)
combined_data
# Out:
#                 TIMESTAMP  AirTemp_Avg  Wind_speed  Wind_direction  \
# 0                     NaN          NaN         NaN             NaN
# 1        6/6/2020 8:45:20         26.6        1.71           148.0
# 2        6/6/2020 8:45:25         26.6        1.45           125.0
# 3        6/6/2020 8:46:20         26.8        1.42           114.0
# 4        6/6/2020 8:46:25         26.8        1.01            21.0
# ...                   ...          ...         ...             ...
# 30991  6/23/2020 16:11:40         42.4        1.72           203.0
# 30992  6/23/2020 16:11:45         42.4        1.24           210.0
# 30993  6/23/2020 16:11:50         42.4        0.75           231.0
# 30994  6/23/2020 16:12:20         42.4        0.97           296.0
# 30995  6/23/2020 16:13:05         42.3        1.65           311.0
#
#        Irradiance_Pyr_NOCT_Avg  NOCT_Mod1_Cent1_Avg  NOCT_Mod1_Cent2_Avg
# 0                          NaN                  NaN                  NaN
# 1                     400.1855                41.82                41.84
# 2                     400.6653                41.89                41.83
# 3                     404.0242                42.02                41.78
# 4                     404.0242                41.95                41.71
# ...                        ...                  ...                  ...
# 30991                 405.5959                56.25                56.07
# 30992                 405.5959                56.28                55.96
# 30993                 405.0982                56.17                55.89
# 30994                 403.6052                55.82                55.33
# 30995                 400.6175                55.79                55.22
#
# [30996 rows x 7 columns]

# %%
# Delete all Wind Direction data within 290 - 250, and 69 - 110
indexWD = combined_data[ ((combined_data['Wind_direction']>250) & (combined_data['Wind_direction']<=290)) | ((combined_data['Wind_direction']>69.99) & (combined_data['Wind_direction']<=110)) ].index  
combined_data.drop(indexWD, axis=0, inplace=True)
combined_data
# Out:
#                 TIMESTAMP  AirTemp_Avg  Wind_speed  Wind_direction  \
# 0                     NaN          NaN         NaN             NaN
# 1        6/6/2020 8:45:20         26.6        1.71           148.0
# 2        6/6/2020 8:45:25         26.6        1.45           125.0
# 3        6/6/2020 8:46:20         26.8        1.42           114.0
# 4        6/6/2020 8:46:25         26.8        1.01            21.0
# ...                   ...          ...         ...             ...
# 30991  6/23/2020 16:11:40         42.4        1.72           203.0
# 30992  6/23/2020 16:11:45         42.4        1.24           210.0
# 30993  6/23/2020 16:11:50         42.4        0.75           231.0
# 30994  6/23/2020 16:12:20         42.4        0.97           296.0
# 30995  6/23/2020 16:13:05         42.3        1.65           311.0
#
#        Irradiance_Pyr_NOCT_Avg  NOCT_Mod1_Cent1_Avg  NOCT_Mod1_Cent2_Avg
# 0                          NaN                  NaN                  NaN
# 1                     400.1855                41.82                41.84
# 2                     400.6653                41.89                41.83
# 3                     404.0242                42.02                41.78
# 4                     404.0242                41.95                41.71
# ...                        ...                  ...                  ...
# 30991                 405.5959                56.25                56.07
# 30992                 405.5959                56.28                55.96
# 30993                 405.0982                56.17                55.89
# 30994                 403.6052                55.82                55.33
# 30995                 400.6175                55.79                55.22
#
# [30996 rows x 7 columns]

# %%
# Delete all Irradiance data below 400 and above 1100
indexIrr = combined_data[ (combined_data['Irradiance_Pyr_NOCT_Avg']<400) | (combined_data['Irradiance_Pyr_NOCT_Avg']>1100) ].index
combined_data.drop(indexIrr, axis=0, inplace=True)
combined_data
# Out:
#                 TIMESTAMP  AirTemp_Avg  Wind_speed  Wind_direction  \
# 0                     NaN          NaN         NaN             NaN
# 1        6/6/2020 8:45:20         26.6        1.71           148.0
# 2        6/6/2020 8:45:25         26.6        1.45           125.0
# 3        6/6/2020 8:46:20         26.8        1.42           114.0
# 4        6/6/2020 8:46:25         26.8        1.01            21.0
# ...                   ...          ...         ...             ...
# 30991  6/23/2020 16:11:40         42.4        1.72           203.0
# 30992  6/23/2020 16:11:45         42.4        1.24           210.0
# 30993  6/23/2020 16:11:50         42.4        0.75           231.0
# 30994  6/23/2020 16:12:20         42.4        0.97           296.0
# 30995  6/23/2020 16:13:05         42.3        1.65           311.0
#
#        Irradiance_Pyr_NOCT_Avg  NOCT_Mod1_Cent1_Avg  NOCT_Mod1_Cent2_Avg
# 0                          NaN                  NaN                  NaN
# 1                     400.1855                41.82                41.84
# 2                     400.6653                41.89                41.83
# 3                     404.0242                42.02                41.78
# 4                     404.0242                41.95                41.71
# ...                        ...                  ...                  ...
# 30991                 405.5959                56.25                56.07
# 30992                 405.5959                56.28                55.96
# 30993                 405.0982                56.17                55.89
# 30994                 403.6052                55.82                55.33
# 30995                 400.6175                55.79                55.22
#
# [30996 rows x 7 columns]

# %%
# Create the T-rise and module_temperature columns
combined_data['module_temperature'] = combined_data[['NOCT_Mod1_Cent1_Avg','NOCT_Mod1_Cent2_Avg']].mean(axis=1)
combined_data['T_RISE'] = combined_data[['NOCT_Mod1_Cent1_Avg','NOCT_Mod1_Cent2_Avg']].mean(axis=1) - combined_data['AirTemp_Avg']
combined_data
# Out:
#                 TIMESTAMP  AirTemp_Avg  Wind_speed  Wind_direction  \
# 0                     NaN          NaN         NaN             NaN
# 1        6/6/2020 8:45:20         26.6        1.71           148.0
# 2        6/6/2020 8:45:25         26.6        1.45           125.0
# 3        6/6/2020 8:46:20         26.8        1.42           114.0
# 4        6/6/2020 8:46:25         26.8        1.01            21.0
# ...                   ...          ...         ...             ...
# 30991  6/23/2020 16:11:40         42.4        1.72           203.0
# 30992  6/23/2020 16:11:45         42.4        1.24           210.0
# 30993  6/23/2020 16:11:50         42.4        0.75           231.0
# 30994  6/23/2020 16:12:20         42.4        0.97           296.0
# 30995  6/23/2020 16:13:05         42.3        1.65           311.0
#
#        Irradiance_Pyr_NOCT_Avg  NOCT_Mod1_Cent1_Avg  NOCT_Mod1_Cent2_Avg  \
# 0                          NaN                  NaN                  NaN
# 1                     400.1855                41.82                41.84
# 2                     400.6653                41.89                41.83
# 3                     404.0242                42.02                41.78
# 4                     404.0242                41.95                41.71
# ...                        ...                  ...                  ...
# 30991                 405.5959                56.25                56.07
# 30992                 405.5959                56.28                55.96
# 30993                 405.0982                56.17                55.89
# 30994                 403.6052                55.82                55.33
# 30995                 400.6175                55.79                55.22
#
#        module_temperature  T_RISE
# 0                     NaN     NaN
# 1                  41.830  15.230
# 2                  41.860  15.260
# 3                  41.900  15.100
# 4                  41.830  15.030
# ...                   ...     ...
# 30991              56.160  13.760
# 30992              56.120  13.720
# 30993              56.030  13.630
# 30994              55.575  13.175
# 30995              55.505  13.205
#
# [30996 rows x 9 columns]

# %%
combined_data["Date"] = pd.to_datetime(combined_data["TIMESTAMP"])
display(combined_data.dtypes)
display(combined_data.head(5))
# Out:
# TIMESTAMP                          object
# AirTemp_Avg                       float64
# Wind_speed                        float64
# Wind_direction                    float64
# Irradiance_Pyr_NOCT_Avg           float64
# NOCT_Mod1_Cent1_Avg               float64
# NOCT_Mod1_Cent2_Avg               float64
# module_temperature                float64
# T_RISE                            float64
# Date                       datetime64[ns]
# dtype: object
#           TIMESTAMP  AirTemp_Avg  Wind_speed  Wind_direction  \
# 0               NaN          NaN         NaN             NaN
# 1  6/6/2020 8:45:20         26.6        1.71           148.0
# 2  6/6/2020 8:45:25         26.6        1.45           125.0
# 3  6/6/2020 8:46:20         26.8        1.42           114.0
# 4  6/6/2020 8:46:25         26.8        1.01            21.0
#
#    Irradiance_Pyr_NOCT_Avg  NOCT_Mod1_Cent1_Avg  NOCT_Mod1_Cent2_Avg  \
# 0                      NaN                  NaN                  NaN
# 1                 400.1855                41.82                41.84
# 2                 400.6653                41.89                41.83
# 3                 404.0242                42.02                41.78
# 4                 404.0242                41.95                41.71
#
#    module_temperature  T_RISE                Date
# 0                 NaN     NaN                 NaT
# 1               41.83   15.23 2020-06-06 08:45:20
# 2               41.86   15.26 2020-06-06 08:45:25
# 3               41.90   15.10 2020-06-06 08:46:20
# 4               41.83   15.03 2020-06-06 08:46:25

# %%
combined_data["date"] = combined_data["Date"].dt.date
combined_data["year"] = combined_data["Date"].dt.year
combined_data["month"] = combined_data["Date"].dt.month
combined_data["day"] = combined_data["Date"].dt.day
combined_data["hour"] = combined_data["Date"].dt.hour
combined_data["minute"] = combined_data["Date"].dt.minute
#noct_csv.drop("TIMESTAMP", axis=1, inplace=True)
combined_data.head(5)
# Out:
#           TIMESTAMP  AirTemp_Avg  Wind_speed  Wind_direction  \
# 0               NaN          NaN         NaN             NaN
# 1  6/6/2020 8:45:20         26.6        1.71           148.0
# 2  6/6/2020 8:45:25         26.6        1.45           125.0
# 3  6/6/2020 8:46:20         26.8        1.42           114.0
# 4  6/6/2020 8:46:25         26.8        1.01            21.0
#
#    Irradiance_Pyr_NOCT_Avg  NOCT_Mod1_Cent1_Avg  NOCT_Mod1_Cent2_Avg  \
# 0                      NaN                  NaN                  NaN
# 1                 400.1855                41.82                41.84
# 2                 400.6653                41.89                41.83
# 3                 404.0242                42.02                41.78
# 4                 404.0242                41.95                41.71
#
#    module_temperature  T_RISE                Date        date    year  month  \
# 0                 NaN     NaN                 NaT         NaT     NaN    NaN
# 1               41.83   15.23 2020-06-06 08:45:20  2020-06-06  2020.0    6.0
# 2               41.86   15.26 2020-06-06 08:45:25  2020-06-06  2020.0    6.0
# 3               41.90   15.10 2020-06-06 08:46:20  2020-06-06  2020.0    6.0
# 4               41.83   15.03 2020-06-06 08:46:25  2020-06-06  2020.0    6.0
#
#    day  hour  minute
# 0  NaN   NaN     NaN
# 1  6.0   8.0    45.0
# 2  6.0   8.0    45.0
# 3  6.0   8.0    46.0
# 4  6.0   8.0    46.0

# %%
combined_data.dropna(axis=0, how='any', inplace=True)
combined_data.sort_values(by=['Date'])
combined_data
# Out:
#                 TIMESTAMP  AirTemp_Avg  Wind_speed  Wind_direction  \
# 1        6/6/2020 8:45:20         26.6        1.71           148.0
# 2        6/6/2020 8:45:25         26.6        1.45           125.0
# 3        6/6/2020 8:46:20         26.8        1.42           114.0
# 4        6/6/2020 8:46:25         26.8        1.01            21.0
# 5        6/6/2020 8:46:30         26.8        1.41           126.0
# ...                   ...          ...         ...             ...
# 30991  6/23/2020 16:11:40         42.4        1.72           203.0
# 30992  6/23/2020 16:11:45         42.4        1.24           210.0
# 30993  6/23/2020 16:11:50         42.4        0.75           231.0
# 30994  6/23/2020 16:12:20         42.4        0.97           296.0
# 30995  6/23/2020 16:13:05         42.3        1.65           311.0
#
#        Irradiance_Pyr_NOCT_Avg  NOCT_Mod1_Cent1_Avg  NOCT_Mod1_Cent2_Avg  \
# 1                     400.1855                41.82                41.84
# 2                     400.6653                41.89                41.83
# 3                     404.0242                42.02                41.78
# 4                     404.0242                41.95                41.71
# 5                     404.0242                42.01                41.69
# ...                        ...                  ...                  ...
# 30991                 405.5959                56.25                56.07
# 30992                 405.5959                56.28                55.96
# 30993                 405.0982                56.17                55.89
# 30994                 403.6052                55.82                55.33
# 30995                 400.6175                55.79                55.22
#
#        module_temperature  T_RISE                Date        date    year  \
# 1                  41.830  15.230 2020-06-06 08:45:20  2020-06-06  2020.0
# 2                  41.860  15.260 2020-06-06 08:45:25  2020-06-06  2020.0
# 3                  41.900  15.100 2020-06-06 08:46:20  2020-06-06  2020.0
# 4                  41.830  15.030 2020-06-06 08:46:25  2020-06-06  2020.0
# 5                  41.850  15.050 2020-06-06 08:46:30  2020-06-06  2020.0
# ...                   ...     ...                 ...         ...     ...
# 30991              56.160  13.760 2020-06-23 16:11:40  2020-06-23  2020.0
# 30992              56.120  13.720 2020-06-23 16:11:45  2020-06-23  2020.0
# 30993              56.030  13.630 2020-06-23 16:11:50  2020-06-23  2020.0
# 30994              55.575  13.175 2020-06-23 16:12:20  2020-06-23  2020.0
# 30995              55.505  13.205 2020-06-23 16:13:05  2020-06-23  2020.0
#
#        month   day  hour  minute
# 1        6.0   6.0   8.0    45.0
# 2        6.0   6.0   8.0    45.0
# 3        6.0   6.0   8.0    46.0
# 4        6.0   6.0   8.0    46.0
# 5        6.0   6.0   8.0    46.0
# ...      ...   ...   ...     ...
# 30991    6.0  23.0  16.0    11.0
# 30992    6.0  23.0  16.0    11.0
# 30993    6.0  23.0  16.0    11.0
# 30994    6.0  23.0  16.0    12.0
# 30995    6.0  23.0  16.0    13.0
#
# [30234 rows x 16 columns]

# %%
# Slice data between 11am and 1pm
indexHour = combined_data[ ((combined_data['hour']<11) | (combined_data['hour']>13))].index
combined_data.drop(indexHour, axis=0, inplace=True)

# %%
# Split the data into a list of daily data
noct_dataframes = split_df(combined_data)
noct_dataframes[0]
# Out:
#               TIMESTAMP  AirTemp_Avg  Wind_speed  Wind_direction  \
# 826   6/6/2020 11:00:00         29.3        1.44           221.0
# 827   6/6/2020 11:00:05         29.3        0.81           218.0
# 828   6/6/2020 11:00:10         29.3        0.95           212.0
# 829   6/6/2020 11:00:15         29.3        0.91           245.0
# 830   6/6/2020 11:00:20         29.3        0.84           186.0
# ...                 ...          ...         ...             ...
# 1705  6/6/2020 13:56:00         31.6        1.10           238.0
# 1706  6/6/2020 13:57:30         31.8        1.37           187.0
# 1707  6/6/2020 13:57:35         31.8        1.66           194.0
# 1708  6/6/2020 13:57:50         31.8        1.34           196.0
# 1709  6/6/2020 13:58:55         32.1        0.93           224.0
#
#       Irradiance_Pyr_NOCT_Avg  NOCT_Mod1_Cent1_Avg  NOCT_Mod1_Cent2_Avg  \
# 826                  746.8678                59.95                59.46
# 827                  745.9084                59.93                59.47
# 828                  745.4288                59.71                59.12
# 829                  745.9084                59.45                58.74
# 830                  744.9491                58.99                58.73
# ...                       ...                  ...                  ...
# 1705                 742.1708                61.05                60.87
# 1706                 739.2855                59.11                59.01
# 1707                 739.2855                59.50                59.39
# 1708                 739.2855                59.55                59.49
# 1709                 740.2421                59.68                59.46
#
#       module_temperature  T_RISE                Date        date    year  \
# 826               59.705  30.405 2020-06-06 11:00:00  2020-06-06  2020.0
# 827               59.700  30.400 2020-06-06 11:00:05  2020-06-06  2020.0
# 828               59.415  30.115 2020-06-06 11:00:10  2020-06-06  2020.0
# 829               59.095  29.795 2020-06-06 11:00:15  2020-06-06  2020.0
# 830               58.860  29.560 2020-06-06 11:00:20  2020-06-06  2020.0
# ...                  ...     ...                 ...         ...     ...
# 1705              60.960  29.360 2020-06-06 13:56:00  2020-06-06  2020.0
# 1706              59.060  27.260 2020-06-06 13:57:30  2020-06-06  2020.0
# 1707              59.445  27.645 2020-06-06 13:57:35  2020-06-06  2020.0
# 1708              59.520  27.720 2020-06-06 13:57:50  2020-06-06  2020.0
# 1709              59.570  27.470 2020-06-06 13:58:55  2020-06-06  2020.0
#
#       month  day  hour  minute
# 826     6.0  6.0  11.0     0.0
# 827     6.0  6.0  11.0     0.0
# 828     6.0  6.0  11.0     0.0
# 829     6.0  6.0  11.0     0.0
# 830     6.0  6.0  11.0     0.0
# ...     ...  ...   ...     ...
# 1705    6.0  6.0  13.0    56.0
# 1706    6.0  6.0  13.0    57.0
# 1707    6.0  6.0  13.0    57.0
# 1708    6.0  6.0  13.0    57.0
# 1709    6.0  6.0  13.0    58.0
#
# [884 rows x 16 columns]

# %%
# Aggregate data by minutes
daily_noct = []
for dataframe in noct_dataframes:
    noct_df = dataframe[["date", "hour","minute", "month", "AirTemp_Avg", "Wind_speed", "Wind_direction", "Irradiance_Pyr_NOCT_Avg", "module_temperature", "T_RISE"]]
    noct_df_agg = noct_df.groupby(["date", "hour", "minute"]).mean()
    noct_df_agg.reset_index(inplace=True)
    daily_noct.append(noct_df_agg)

daily_noct[0]
# Out:
#            date  hour  minute  month  AirTemp_Avg  Wind_speed  Wind_direction  \
# 0    2020-06-06  11.0     0.0    6.0       29.175    0.847500      178.250000
# 1    2020-06-06  11.0     1.0    6.0       29.000    0.603333      147.500000
# 2    2020-06-06  11.0     2.0    6.0       29.050    1.230000      204.750000
# 3    2020-06-06  11.0     3.0    6.0       29.100    1.006000      218.500000
# 4    2020-06-06  11.0     4.0    6.0       29.150    1.365000      187.750000
# ..          ...   ...     ...    ...          ...         ...             ...
# 161  2020-06-06  13.0    54.0    6.0       31.600    0.895000      245.000000
# 162  2020-06-06  13.0    55.0    6.0       31.600    1.290000      235.000000
# 163  2020-06-06  13.0    56.0    6.0       31.600    1.100000      238.000000
# 164  2020-06-06  13.0    57.0    6.0       31.800    1.456667      192.333333
# 165  2020-06-06  13.0    58.0    6.0       32.100    0.930000      224.000000
#
#      Irradiance_Pyr_NOCT_Avg  module_temperature     T_RISE
# 0                 745.464667           59.165833  29.990833
# 1                 743.820050           59.995833  30.995833
# 2                 744.820225           59.926250  30.876250
# 3                 747.819070           60.548000  31.448000
# 4                 749.017200           60.156250  31.006250
# ..                       ...                 ...        ...
# 161               742.894900           59.902500  28.302500
# 162               742.170800           60.055000  28.455000
# 163               742.170800           60.960000  29.360000
# 164               739.285500           59.341667  27.541667
# 165               740.242100           59.570000  27.470000
#
# [166 rows x 10 columns]

# %%
len(daily_noct)
# Out:
# 13

# %%
# Cleaning ambient temperatures
# If min amb temp around 35, delete data where (max - min) amb temp are above 5 degC
# Otherwise, Delete all Ambient Temperature data below 5 degC and above 35 degC if max Tamb < 35
for noct in daily_noct:
    indexShift = noct[ (noct['AirTemp_Avg'] - noct['AirTemp_Avg'].shift(1)) < 0 ].index
    noct.drop(indexShift, axis=0, inplace=True)
    if noct['AirTemp_Avg'].min() >= 35:
        while (noct['AirTemp_Avg'].max() - noct['AirTemp_Avg'].min()) > 5:
            noct.drop(noct[(noct['AirTemp_Avg'] == noct['AirTemp_Avg'].max()) | (noct["AirTemp_Avg"] == noct['AirTemp_Avg'].min())].index, axis=0, inplace=True)
    else:
        indexTamb = noct[ ((noct['AirTemp_Avg']<5) & (noct['AirTemp_Avg']>35))].index
        noct.drop(indexTamb, axis=0, inplace=True)
    #print(f"{noct.index[0][0]}: \n{noct}")

# %%
# Indice 5 is known to have only afternoon data. This should be removed
daily_noct[5]
# Out:
#            date  hour  minute  month  AirTemp_Avg  Wind_speed  Wind_direction  \
# 0    2020-06-16  11.0     0.0    6.0    36.500000    1.185000      109.250000
# 1    2020-06-16  11.0     1.0    6.0    36.600000    0.990000      196.500000
# 2    2020-06-16  11.0     2.0    6.0    36.866667    1.328333      209.833333
# 6    2020-06-16  11.0     6.0    6.0    36.400000    1.510000      154.500000
# 7    2020-06-16  11.0     7.0    6.0    36.500000    1.366000      197.400000
# ..          ...   ...     ...    ...          ...         ...             ...
# 164  2020-06-16  13.0    54.0    6.0    39.400000    1.552500      236.750000
# 165  2020-06-16  13.0    55.0    6.0    39.700000    1.152500      222.125000
# 166  2020-06-16  13.0    56.0    6.0    39.700000    1.312000      213.300000
# 168  2020-06-16  13.0    58.0    6.0    39.500000    1.386667      191.333333
# 169  2020-06-16  13.0    59.0    6.0    39.700000    1.267500      161.875000
#
#      Irradiance_Pyr_NOCT_Avg  module_temperature     T_RISE
# 0                 812.343550           64.900000  28.400000
# 1                 817.197750           64.096250  27.496250
# 2                 819.645233           64.583333  27.716667
# 6                 828.026250           65.065000  28.665000
# 7                 829.619480           64.582000  28.082000
# ..                       ...                 ...        ...
# 164               800.766400           67.423750  28.023750
# 165               798.589325           67.715000  28.015000
# 166               796.312780           67.700500  28.000500
# 168               791.436267           68.038333  28.538333
# 169               788.574900           67.621250  27.921250
#
# [106 rows x 10 columns]

# %%
# We want to delete all the data which do not have points before and after noon
to_remove = []   # This will hold the indices of the dataframe list to be removed
for i, noct in enumerate(daily_noct):
    am = False
    pm = False
    if noct['hour'].min() == 11:
        am = True
    if noct['hour'].max() in [12,13]:
        pm = True
    if (am == False or pm == False):
        to_remove.append(i)
# Sort the indice of dataframes to drop
# By starting from higher to lower indices, we're guaranteed that the indices on the dataframe will remain unmodified while deleting
for x in sorted(to_remove, reverse=True):
    del daily_noct[x]

# %%
# Checking that the previous indice 5 was effectively deleted.
daily_noct[5]
# Out:
#            date  hour  minute  month  AirTemp_Avg  Wind_speed  Wind_direction  \
# 0    2020-06-16  11.0     0.0    6.0    36.500000    1.185000      109.250000
# 1    2020-06-16  11.0     1.0    6.0    36.600000    0.990000      196.500000
# 2    2020-06-16  11.0     2.0    6.0    36.866667    1.328333      209.833333
# 6    2020-06-16  11.0     6.0    6.0    36.400000    1.510000      154.500000
# 7    2020-06-16  11.0     7.0    6.0    36.500000    1.366000      197.400000
# ..          ...   ...     ...    ...          ...         ...             ...
# 164  2020-06-16  13.0    54.0    6.0    39.400000    1.552500      236.750000
# 165  2020-06-16  13.0    55.0    6.0    39.700000    1.152500      222.125000
# 166  2020-06-16  13.0    56.0    6.0    39.700000    1.312000      213.300000
# 168  2020-06-16  13.0    58.0    6.0    39.500000    1.386667      191.333333
# 169  2020-06-16  13.0    59.0    6.0    39.700000    1.267500      161.875000
#
#      Irradiance_Pyr_NOCT_Avg  module_temperature     T_RISE
# 0                 812.343550           64.900000  28.400000
# 1                 817.197750           64.096250  27.496250
# 2                 819.645233           64.583333  27.716667
# 6                 828.026250           65.065000  28.665000
# 7                 829.619480           64.582000  28.082000
# ..                       ...                 ...        ...
# 164               800.766400           67.423750  28.023750
# 165               798.589325           67.715000  28.015000
# 166               796.312780           67.700500  28.000500
# 168               791.436267           68.038333  28.538333
# 169               788.574900           67.621250  27.921250
#
# [106 rows x 10 columns]

# %%
len(daily_noct)
# Out:
# 13

# %%
'''
# Set the dependent and independent variables list for the model.
# Multiple linear regression: T_RISE = f(Irradiance, Wind_speed)
target = "module_temperature"
feature_names = ['irradiance', 'wind_speed', 'wind_direction', 'ambient_temperature']
full_model_dict = {}


for noct in daily_noct:
    # Rename columns
    noct.rename(columns={'AirTemp_Avg':'ambient_temperature', 'Wind_speed':'wind_speed', 'Wind_direction':'wind_direction', 'Irradiance_Pyr_NOCT_Avg':'irradiance'}, inplace=True)
    # Split into training and testing windows
    X_train, X_test, y_train, y_test = train_test_split(noct[feature_names], noct[target], random_state=11)
    
    # Let's set the model training for a very long time, 
    # but with an EarlyStopping callback so it stops automatically when it stops improving.
    model = create_model()
    history = fit_model(model, 'val_loss', 100000)
    
    # define filename for saving the model
    s = noct['date'].unique()[0]
    filepath = 'models/dnn_noct_' + s
    
    # Save a model using the HDF5 format
    saving_model(model, filepath+'.h5')
    saving_history(history, filepath)
 '''
# Out:
# '\n# Set the dependent and independent variables list for the model.\n# Multiple linear regression: T_RISE = f(Irradiance, Wind_speed)\ntarget = "module_temperature"\nfeature_names = [\'irradiance\', \'wind_speed\', \'wind_direction\', \'ambient_temperature\']\nfull_model_dict = {}\n\n\nfor noct in daily_noct:\n    # Rename columns\n    noct.rename(columns={\'AirTemp_Avg\':\'ambient_temperature\', \'Wind_speed\':\'wind_speed\', \'Wind_direction\':\'wind_direction\', \'Irradiance_Pyr_NOCT_Avg\':\'irradiance\'}, inplace=True)\n    # Split into training and testing windows\n    X_train, X_test, y_train, y_test = train_test_split(noct[feature_names], noct[target], random_state=11)\n    \n    # Let\'s set the model training for a very long time, \n    # but with an EarlyStopping callback so it stops automatically when it stops improving.\n    model = create_model()\n    history = fit_model(model, \'val_loss\', 100000)\n    \n    # define filename for saving the model\n    s = noct[\'date\'].unique()[0]\n    filepath = \'models/dnn_noct_\' + s\n    \n    # Save a model using the HDF5 format\n    saving_model(model, filepath+\'.h5\')\n    saving_history(history, filepath)\n '

# %%
'''
model = loading_model('models/dnn_noct_2023-06-01.h5')
model.summary()
'''
# Out:
# "\nmodel = loading_model('models/dnn_noct_2023-06-01.h5')\nmodel.summary()\n"

# %%
# history_dict = loading_history('models/dnn_noct_2023-06-01')

# %%
'''
# Calculate predictions
predictions = calculate_predictions(model)

# Plot training history
plot_training(history_dict, 'plots/dnn_noct_2023-06-01.png')
'''
'''
# Calculate predictions
PredTestSet = model.predict(X_train)
PredValSet = model.predict(X_test)
'''
# Out:
# '\n# Calculate predictions\nPredTestSet = model.predict(X_train)\nPredValSet = model.predict(X_test)\n'

# %%
# Combining the list of dataframes into a single one
combined_daily_noct = pd.concat(daily_noct, axis=0, join='inner')
combined_daily_noct
# Out:
#            date  hour  minute  month  AirTemp_Avg  Wind_speed  Wind_direction  \
# 0    2020-06-06  11.0     0.0    6.0    29.175000    0.847500      178.250000
# 2    2020-06-06  11.0     2.0    6.0    29.050000    1.230000      204.750000
# 3    2020-06-06  11.0     3.0    6.0    29.100000    1.006000      218.500000
# 4    2020-06-06  11.0     4.0    6.0    29.150000    1.365000      187.750000
# 5    2020-06-06  11.0     5.0    6.0    29.480000    0.910000      199.600000
# ..          ...   ...     ...    ...          ...         ...             ...
# 160  2020-06-23  13.0    51.0    6.0    41.300000    1.066667      301.000000
# 163  2020-06-23  13.0    54.0    6.0    41.000000    1.159167       65.916665
# 164  2020-06-23  13.0    55.0    6.0    41.000000    0.866667      186.500000
# 165  2020-06-23  13.0    56.0    6.0    41.183333    0.583333      138.000000
# 168  2020-06-23  13.0    59.0    6.0    41.209091    1.067273      212.363636
#
#      Irradiance_Pyr_NOCT_Avg  module_temperature     T_RISE
# 0                 745.464667           59.165833  29.990833
# 2                 744.820225           59.926250  30.876250
# 3                 747.819070           60.548000  31.448000
# 4                 749.017200           60.156250  31.006250
# 5                 747.814700           60.291000  30.811000
# ..                       ...                 ...        ...
# 160               796.910500           68.425000  27.125000
# 163               790.191975           69.559583  28.559583
# 164               786.376467           70.145000  29.145000
# 165               783.224467           69.487500  28.304167
# 168               778.193836           69.535455  28.326364
#
# [1324 rows x 10 columns]

# %%
# Simple Regression using T_RISE
'''
# Set the dependent and independent variables list for the model.
# Simple linear regression: T_RISE = f(Irradiance)
model = LinearRegression(fit_intercept=True)
model_dict = {}
x = combined_daily_noct.loc[:, "Irradiance_Pyr_NOCT_Avg"].values.reshape(-1, 1)  # values converts it into a numpy array
y = combined_daily_noct.loc[:, "T_RISE"].values.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column
model.fit(x, y)
combined_daily_noct['predicted'] = model.predict(x)
noct_est = 20 + model.intercept_ + model.coef_ * 800
plot = combined_daily_noct.hvplot.scatter(x='Irradiance_Pyr_NOCT_Avg',
                               y='T_RISE',
                               xlabel = "Irradiance",
                               ylabel="Temperature Rise",
                               title=f"Temp Rise vs. Irradiance for {combined_daily_noct.index[0]}",
                               color="blue"
                               ).opts(yformatter='%.0f') * combined_daily_noct.hvplot.line(x='Irradiance_Pyr_NOCT_Avg',
                                                                                       y='predicted',
                                                                                       color='red')
#model_dict[all_noct.index[0]] = {"model": model, "plot": plot, "intercept": round(float(model.intercept_),2), "slope": round(float(model.coef_),2), "noct": noct_est, "r_square": round(float(model.score(x, y)),2)}
'''
# Out:
# '\n# Set the dependent and independent variables list for the model.\n# Simple linear regression: T_RISE = f(Irradiance)\nmodel = LinearRegression(fit_intercept=True)\nmodel_dict = {}\nx = combined_daily_noct.loc[:, "Irradiance_Pyr_NOCT_Avg"].values.reshape(-1, 1)  # values converts it into a numpy array\ny = combined_daily_noct.loc[:, "T_RISE"].values.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column\nmodel.fit(x, y)\ncombined_daily_noct[\'predicted\'] = model.predict(x)\nnoct_est = 20 + model.intercept_ + model.coef_ * 800\nplot = combined_daily_noct.hvplot.scatter(x=\'Irradiance_Pyr_NOCT_Avg\',\n                               y=\'T_RISE\',\n                               xlabel = "Irradiance",\n                               ylabel="Temperature Rise",\n                               title=f"Temp Rise vs. Irradiance for {combined_daily_noct.index[0]}",\n                               color="blue"\n                               ).opts(yformatter=\'%.0f\') * combined_daily_noct.hvplot.line(x=\'Irradiance_Pyr_NOCT_Avg\',\n                                                                                       y=\'predicted\',\n                                                                                       color=\'red\')\n#model_dict[all_noct.index[0]] = {"model": model, "plot": plot, "intercept": round(float(model.intercept_),2), "slope": round(float(model.coef_),2), "noct": noct_est, "r_square": round(float(model.score(x, y)),2)}\n'

# %%
# Multiple Regression using T_RISE
'''
# Set the dependent and independent variables list for the model.
# Multiple linear regression: T_RISE = f(Irradiance, Wind_speed)
full_model = LinearRegression(fit_intercept=True)
full_model_dict = {}

X = combined_daily_noct[['Wind_speed','Irradiance_Pyr_NOCT_Avg']]
Y = combined_daily_noct['T_RISE']
full_model = ols("Y ~ X", combined_daily_noct).fit()
#anova_results = anova_lm(model)
summary = full_model.summary()
results = full_model.params
r_square = full_model.rsquared
noct_est = 20 + results[0] + results[1] + results[2] * 800
Tamb_avg = float(combined_daily_noct["AirTemp_Avg"].mean())
WS_avg = float(combined_daily_noct["Wind_speed"].mean())
#full_model_dict[noct.index[0]] = {"model": model, "summary": summary, "parameters": results, "noct": noct_est, "r_square": r_square, "ambient_temp": Tamb_avg, "wind_speed": WS_avg, "ws_correction": int(results[1])}
'''
# Out:
# '\n# Set the dependent and independent variables list for the model.\n# Multiple linear regression: T_RISE = f(Irradiance, Wind_speed)\nfull_model = LinearRegression(fit_intercept=True)\nfull_model_dict = {}\n\nX = combined_daily_noct[[\'Wind_speed\',\'Irradiance_Pyr_NOCT_Avg\']]\nY = combined_daily_noct[\'T_RISE\']\nfull_model = ols("Y ~ X", combined_daily_noct).fit()\n#anova_results = anova_lm(model)\nsummary = full_model.summary()\nresults = full_model.params\nr_square = full_model.rsquared\nnoct_est = 20 + results[0] + results[1] + results[2] * 800\nTamb_avg = float(combined_daily_noct["AirTemp_Avg"].mean())\nWS_avg = float(combined_daily_noct["Wind_speed"].mean())\n#full_model_dict[noct.index[0]] = {"model": model, "summary": summary, "parameters": results, "noct": noct_est, "r_square": r_square, "ambient_temp": Tamb_avg, "wind_speed": WS_avg, "ws_correction": int(results[1])}\n'

# %%
'''
# Display Simple Linear Regression Results
#display(model_dict[key]['ws_correction'])
#display(model_dict[key]['ambient_temp'])
#display(model_dict[key]['wind_speed'])
display(noct_est)
display(round(float(model.score(x, y)),2))
print(" ")
display(plot)
'''
# Out:
# '\n# Display Simple Linear Regression Results\n#display(model_dict[key][\'ws_correction\'])\n#display(model_dict[key][\'ambient_temp\'])\n#display(model_dict[key][\'wind_speed\'])\ndisplay(noct_est)\ndisplay(round(float(model.score(x, y)),2))\nprint(" ")\ndisplay(plot)\n'

# %%
#combined_daily_noct.head(3)

# %%
combined_df = combined_daily_noct[['AirTemp_Avg', 'Wind_speed', 'Wind_direction', 'Irradiance_Pyr_NOCT_Avg', 'module_temperature', 'T_RISE']]
combined_df.rename(columns={'AirTemp_Avg':'ambient_temperature', 'Wind_speed':'wind_speed', 'Wind_direction':'wind_direction', 'Irradiance_Pyr_NOCT_Avg':'irradiance'}, inplace=True)
combined_df
# Out:
# C:\Users\Kuitche\anaconda3\envs\dev\lib\site-packages\pandas\core\frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#      ambient_temperature  wind_speed  wind_direction  irradiance  \
# 0              29.175000    0.847500      178.250000  745.464667
# 2              29.050000    1.230000      204.750000  744.820225
# 3              29.100000    1.006000      218.500000  747.819070
# 4              29.150000    1.365000      187.750000  749.017200
# 5              29.480000    0.910000      199.600000  747.814700
# ..                   ...         ...             ...         ...
# 160            41.300000    1.066667      301.000000  796.910500
# 163            41.000000    1.159167       65.916665  790.191975
# 164            41.000000    0.866667      186.500000  786.376467
# 165            41.183333    0.583333      138.000000  783.224467
# 168            41.209091    1.067273      212.363636  778.193836
#
#      module_temperature     T_RISE
# 0             59.165833  29.990833
# 2             59.926250  30.876250
# 3             60.548000  31.448000
# 4             60.156250  31.006250
# 5             60.291000  30.811000
# ..                  ...        ...
# 160           68.425000  27.125000
# 163           69.559583  28.559583
# 164           70.145000  29.145000
# 165           69.487500  28.304167
# 168           69.535455  28.326364
#
# [1324 rows x 6 columns]

# %%
'''
X_train, X_test, y_train, y_test = train_test_split(combined_df.irradiance.values.reshape(-1,1), combined_df.T_RISE.values, random_state=11)
display(X_train.shape)
display(X_test.shape)
'''
# Out:
# '\nX_train, X_test, y_train, y_test = train_test_split(combined_df.irradiance.values.reshape(-1,1), combined_df.T_RISE.values, random_state=11)\ndisplay(X_train.shape)\ndisplay(X_test.shape)\n'

# %%
'''
linear_regression = LinearRegression()
linear_regression.fit(X=X_train, y=y_train)
LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
'''
# Out:
# '\nlinear_regression = LinearRegression()\nlinear_regression.fit(X=X_train, y=y_train)\nLinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)\n'

# %%
#display(linear_regression.coef_)
#display(linear_regression.intercept_)

# %%
#predicted = linear_regression.predict(X_test)
#expected = y_test
'''
for p, e in zip(predicted[::5], expected[::5]):
    print(f'predicted: {p:.2f}, expected: {e:.2f}')
'''
# Out:
# "\nfor p, e in zip(predicted[::5], expected[::5]):\n    print(f'predicted: {p:.2f}, expected: {e:.2f}')\n"

# %%
'''
noct = 20 + linear_regression.coef_* 800 + linear_regression.intercept_
print(f'R_SQUARE: {round(float(linear_regression.score(x, y)),2)}')
print(f'ESTIMATED_NOCT: {noct}')
'''
# Out:
# "\nnoct = 20 + linear_regression.coef_* 800 + linear_regression.intercept_\nprint(f'R_SQUARE: {round(float(linear_regression.score(x, y)),2)}')\nprint(f'ESTIMATED_NOCT: {noct}')\n"

# %%
#predict = (lambda x: linear_regression.coef_ * x + linear_regression.intercept_)

# %%
'''
# Visualizing the dataset with the Regression line
axes = sns.scatterplot(data=combined_df, x='irradiance', y='T_RISE', hue='T_RISE', palette='winter', legend=False)
#axes.set_ylim(400,1000)
x = np.array([min(combined_df.irradiance.values), max(combined_df.irradiance.values)])
y = predict(x)
line = plt.plot(x,y)
'''
# Out:
# "\n# Visualizing the dataset with the Regression line\naxes = sns.scatterplot(data=combined_df, x='irradiance', y='T_RISE', hue='T_RISE', palette='winter', legend=False)\n#axes.set_ylim(400,1000)\nx = np.array([min(combined_df.irradiance.values), max(combined_df.irradiance.values)])\ny = predict(x)\nline = plt.plot(x,y)\n"

# %% [markdown]
# # Multiple Linear Regression

# %%
target = "module_temperature"
feature_names = ['irradiance', 'wind_speed', 'wind_direction', 'ambient_temperature']

# %%
display(combined_df[feature_names].shape)
display(combined_df[target].shape)
# Out:
# (1324, 4)
# (1324,)

# %%
sample_df = combined_df.sample(frac=0.1, random_state=17)

# %%
for feature in feature_names:
    plt.figure(figsize=(16,9))
    sns.scatterplot(data=sample_df, x=feature, y=target, hue=target, palette='cool', legend=False)

# %%
sample_df[feature_names].corr()
# Out:
#                      irradiance  wind_speed  wind_direction  \
# irradiance             1.000000   -0.050097       -0.142583
# wind_speed            -0.050097    1.000000        0.041201
# wind_direction        -0.142583    0.041201        1.000000
# ambient_temperature    0.424253   -0.046399        0.126373
#
#                      ambient_temperature
# irradiance                      0.424253
# wind_speed                     -0.046399
# wind_direction                  0.126373
# ambient_temperature             1.000000

# %%
X_train, X_test, y_train, y_test = train_test_split(combined_df[feature_names], combined_df[target], random_state=11)
display(X_train.shape)
display(X_test.shape)
# Out:
# (993, 4)
# (331, 4)

# %%
linear_regression = LinearRegression()
linear_regression.fit(X=X_train, y=y_train)
LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# Out:
# LinearRegression(normalize=False)

# %%
# Regression coefficients
for i, name in enumerate(feature_names):
    print(f'{name:>10}: {linear_regression.coef_[i]}')
linear_regression.intercept_
# Out:
# irradiance: 0.020787809500007096
# wind_speed: -2.1350546612305186
# wind_direction: -0.009250483307031383
# ambient_temperature: 0.9435501127585652
# 18.898135593955395

# %%
# NOCT estimate
noct_est = linear_regression.intercept_ + 800*linear_regression.coef_[0] + 1*linear_regression.coef_[1] + 120*linear_regression.coef_[2] + 20*linear_regression.coef_[3]
noct_est
# Out:
# 51.15427279105809

# %%
# Testing the model
predicted = linear_regression.predict(X_test)
expected = y_test

# %%
# Visualizing the Expected vs. Predicted
df = pd.DataFrame()
df['Expected'] = pd.Series(expected)
df['Predicted'] = pd.Series(predicted)
figure = plt.figure(figsize=(9,9))
axes = sns.scatterplot(data=df, x= 'Expected', y='Predicted', hue='Predicted', palette='cool', legend=False)

# Set the x- and y-axes limits to use the same scale along both axes
start = min(expected.min(), predicted.min())
end = max(expected.max(), predicted.max())
axes.set_xlim(start, end)
axes.set_ylim(start, end)

line = plt.plot([start, end], [start, end], 'k--')
plt.savefig(plotpath)

# %%
# Regression Model Metrics
print(f'R_SQUARE = {metrics.r2_score(expected, predicted)}')
print(f'MSE = {metrics.mean_squared_error(expected, predicted)}')
# Out:
# R_SQUARE = 0.7887237877137697
# MSE = 3.6909721008418153

# %% [markdown]
# # Choosing the best Model

# %%
# Let's run several regression estimators
estimators = {
    'LinearRegression': linear_regression,
    'ElasticNet': ElasticNet(),
    'Lasso': Lasso(),
    'Ridge': Ridge()
}

# %%
# We run estimators using k-fold cross-validation with a KFold object and the cross_val_score function
for estimator_name, estimator_object in estimators.items():
    kfold = KFold(n_splits=10, random_state=11, shuffle=True)
    scores = cross_val_score(estimator=estimator_object, X=combined_df[feature_names], y=combined_df[target], cv=kfold, scoring='r2')
    mse = cross_val_score(estimator=estimator_object, X=combined_df[feature_names], y=combined_df[target], cv=kfold, scoring='neg_mean_squared_error')
    print(f'{estimator_name:>16}: mean of r2 scores = {scores.mean():.3f} **** mean of MSE scores = {mse.mean():.2f}')
# Out:
# LinearRegression: mean of r2 scores = 0.789 **** mean of MSE scores = -3.40
#       ElasticNet: mean of r2 scores = 0.765 **** mean of MSE scores = -3.79
#            Lasso: mean of r2 scores = 0.764 **** mean of MSE scores = -3.81
#            Ridge: mean of r2 scores = 0.789 **** mean of MSE scores = -3.40

# %% [markdown]
# # Using Deep Learning

# %%
# Import the necessary libraries
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import numpy
from keras.optimizers import Adam
import keras
from matplotlib import pyplot
from keras.callbacks import EarlyStopping
import pandas as pd 
from sklearn.preprocessing import LabelEncoder

# %%
# Split into training and testing windows
X_train, X_test, y_train, y_test = train_test_split(combined_df[feature_names], combined_df[target], random_state=11)

# %%
'''
# initializing the tunner 
tuner = kt.Hyperband(model_builder,
                     objective='val_loss',
                     max_epochs=1300,
                    )
'''
# Out:
# "\n# initializing the tunner \ntuner = kt.Hyperband(model_builder,\n                     objective='val_loss',\n                     max_epochs=1300,\n                    )\n"

# %%
# Early stopping in keras
# The patience parameter represents the number of epochs with no improvement after training is stopped.
#stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience = 50)

# %%
'''
# First, let us search for the optimum number of nodes in the hidden layer by running the tunner.search() method.
# Seaching the tunner 
tuner.search(X_train, y_train, validation_data=(X_test, y_test), callbacks=[stop_early])
# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]
# printing the optimal number of nodes 
print('The optimal number of node in the hidden layer is: ', best_hps.get('units'))
'''
# Out:
# "\n# First, let us search for the optimum number of nodes in the hidden layer by running the tunner.search() method.\n# Seaching the tunner \ntuner.search(X_train, y_train, validation_data=(X_test, y_test), callbacks=[stop_early])\n# Get the optimal hyperparameters\nbest_hps=tuner.get_best_hyperparameters(num_trials=1)[0]\n# printing the optimal number of nodes \nprint('The optimal number of node in the hidden layer is: ', best_hps.get('units'))\n"

# %%
'''
# creating model with the optimum parameters
model = tuner.hypermodel.build(best_hps)
# fixed max max epohcs to 1300
#Training_model = model.fit(X_train, y_train, epochs=1300, validation_split=0.2, callbacks=[stop_early])
# val_loss 
#val_acc_per_epoch = Training_model.history['val_loss']
# printing optimum eppoc
#best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
#print('Best epoch:',  best_epoch)
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=1300, batch_size=100, verbose=2, callbacks=[stop_early])
'''
# Out:
# "\n# creating model with the optimum parameters\nmodel = tuner.hypermodel.build(best_hps)\n# fixed max max epohcs to 1300\n#Training_model = model.fit(X_train, y_train, epochs=1300, validation_split=0.2, callbacks=[stop_early])\n# val_loss \n#val_acc_per_epoch = Training_model.history['val_loss']\n# printing optimum eppoc\n#best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1\n#print('Best epoch:',  best_epoch)\nhistory = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=1300, batch_size=100, verbose=2, callbacks=[stop_early])\n"

# %%
'''
# Creating modele complinin
model = tf.keras.Sequential([tf.keras.layers.InputLayer(
    input_shape=4,),
  tf.keras.layers.Dense(best_hps, activation = tf.keras.activations.relu),
  tf.keras.layers.Dense(1)
])
# Complining the model
model.compile(loss=tf.keras.losses.mae,
                optimizer=tf.keras.optimizers.Adam(),
                metrics=['mae'])
# training the model on optimum epochs
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=1300, batch_size=100, verbose=2, callbacks=[stop_early])
'''
# Out:
# "\n# Creating modele complinin\nmodel = tf.keras.Sequential([tf.keras.layers.InputLayer(\n    input_shape=4,),\n  tf.keras.layers.Dense(best_hps, activation = tf.keras.activations.relu),\n  tf.keras.layers.Dense(1)\n])\n# Complining the model\nmodel.compile(loss=tf.keras.losses.mae,\n                optimizer=tf.keras.optimizers.Adam(),\n                metrics=['mae'])\n# training the model on optimum epochs\nhistory = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=1300, batch_size=100, verbose=2, callbacks=[stop_early])\n"

# %%
# Let's set the model training for a very long time, 
# but with an EarlyStopping callback so it stops automatically when it stops improving.
model = create_model()
history = fit_model(model, 'val_loss', 100000)
# Out:
# Epoch 1/100000
# C:\Users\Kuitche\anaconda3\envs\dev\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 10/10 - 0s - loss: 11236.3486 - val_loss: 1637.2241 - 469ms/epoch - 47ms/step
# Epoch 2/100000
# 10/10 - 0s - loss: 3271.3140 - val_loss: 1814.3656 - 45ms/epoch - 4ms/step
# Epoch 3/100000
# 10/10 - 0s - loss: 674.7041 - val_loss: 742.5001 - 41ms/epoch - 4ms/step
# Epoch 4/100000
# 10/10 - 0s - loss: 648.3073 - val_loss: 207.6195 - 42ms/epoch - 4ms/step
# Epoch 5/100000
# 10/10 - 0s - loss: 208.7545 - val_loss: 228.5364 - 44ms/epoch - 4ms/step
# Epoch 6/100000
# 10/10 - 0s - loss: 121.5244 - val_loss: 85.9865 - 40ms/epoch - 4ms/step
# Epoch 7/100000
# 10/10 - 0s - loss: 71.6722 - val_loss: 41.6331 - 43ms/epoch - 4ms/step
# Epoch 8/100000
# 10/10 - 0s - loss: 38.0623 - val_loss: 32.1831 - 40ms/epoch - 4ms/step
# Epoch 9/100000
# 10/10 - 0s - loss: 27.1723 - val_loss: 24.8613 - 43ms/epoch - 4ms/step
# Epoch 10/100000
# 10/10 - 0s - loss: 22.4736 - val_loss: 20.8817 - 41ms/epoch - 4ms/step
# Epoch 11/100000
# 10/10 - 0s - loss: 20.2641 - val_loss: 18.7677 - 41ms/epoch - 4ms/step
# Epoch 12/100000
# 10/10 - 0s - loss: 18.3865 - val_loss: 17.5958 - 42ms/epoch - 4ms/step
# Epoch 13/100000
# 10/10 - 0s - loss: 17.3685 - val_loss: 16.4914 - 39ms/epoch - 4ms/step
# Epoch 14/100000
# 10/10 - 0s - loss: 16.2594 - val_loss: 15.6492 - 41ms/epoch - 4ms/step
# Epoch 15/100000
# 10/10 - 0s - loss: 15.4225 - val_loss: 14.8071 - 40ms/epoch - 4ms/step
# Epoch 16/100000
# 10/10 - 0s - loss: 14.5664 - val_loss: 14.0917 - 41ms/epoch - 4ms/step
# Epoch 17/100000
# 10/10 - 0s - loss: 13.8101 - val_loss: 13.4627 - 40ms/epoch - 4ms/step
# Epoch 18/100000
# 10/10 - 0s - loss: 13.1771 - val_loss: 12.9357 - 42ms/epoch - 4ms/step
# Epoch 19/100000
# 10/10 - 0s - loss: 12.5936 - val_loss: 12.4088 - 40ms/epoch - 4ms/step
# Epoch 20/100000
# 10/10 - 0s - loss: 12.0632 - val_loss: 11.9945 - 40ms/epoch - 4ms/step
# Epoch 21/100000
# 10/10 - 0s - loss: 11.6295 - val_loss: 11.6413 - 40ms/epoch - 4ms/step
# Epoch 22/100000
# 10/10 - 0s - loss: 11.2976 - val_loss: 11.3340 - 41ms/epoch - 4ms/step
# Epoch 23/100000
# 10/10 - 0s - loss: 11.1282 - val_loss: 11.0740 - 40ms/epoch - 4ms/step
# Epoch 24/100000
# 10/10 - 0s - loss: 10.8416 - val_loss: 11.0068 - 41ms/epoch - 4ms/step
# Epoch 25/100000
# 10/10 - 0s - loss: 10.6817 - val_loss: 10.7507 - 41ms/epoch - 4ms/step
# Epoch 26/100000
# 10/10 - 0s - loss: 10.4782 - val_loss: 10.6238 - 47ms/epoch - 5ms/step
# Epoch 27/100000
# 10/10 - 0s - loss: 10.3777 - val_loss: 10.4801 - 42ms/epoch - 4ms/step
# Epoch 28/100000
# 10/10 - 0s - loss: 10.2590 - val_loss: 10.3792 - 42ms/epoch - 4ms/step
# Epoch 29/100000
# 10/10 - 0s - loss: 10.1263 - val_loss: 10.3206 - 38ms/epoch - 4ms/step
# Epoch 30/100000
# 10/10 - 0s - loss: 10.0244 - val_loss: 10.2713 - 42ms/epoch - 4ms/step
# Epoch 31/100000
# 10/10 - 0s - loss: 9.9841 - val_loss: 10.1861 - 42ms/epoch - 4ms/step
# Epoch 32/100000
# 10/10 - 0s - loss: 9.9092 - val_loss: 10.0882 - 42ms/epoch - 4ms/step
# Epoch 33/100000
# 10/10 - 0s - loss: 9.8222 - val_loss: 10.0438 - 42ms/epoch - 4ms/step
# Epoch 34/100000
# 10/10 - 0s - loss: 9.7847 - val_loss: 9.9583 - 42ms/epoch - 4ms/step
# Epoch 35/100000
# 10/10 - 0s - loss: 9.7055 - val_loss: 9.9395 - 53ms/epoch - 5ms/step
# Epoch 36/100000
# 10/10 - 0s - loss: 9.6274 - val_loss: 9.8325 - 39ms/epoch - 4ms/step
# Epoch 37/100000
# 10/10 - 0s - loss: 9.5983 - val_loss: 9.7654 - 40ms/epoch - 4ms/step
# Epoch 38/100000
# 10/10 - 0s - loss: 9.5557 - val_loss: 9.9074 - 43ms/epoch - 4ms/step
# Epoch 39/100000
# 10/10 - 0s - loss: 9.4480 - val_loss: 9.6230 - 40ms/epoch - 4ms/step
# Epoch 40/100000
# 10/10 - 0s - loss: 9.4474 - val_loss: 9.5731 - 41ms/epoch - 4ms/step
# Epoch 41/100000
# 10/10 - 0s - loss: 9.4760 - val_loss: 9.8360 - 41ms/epoch - 4ms/step
# Epoch 42/100000
# 10/10 - 0s - loss: 9.3345 - val_loss: 9.4388 - 40ms/epoch - 4ms/step
# Epoch 43/100000
# 10/10 - 0s - loss: 9.2470 - val_loss: 9.3919 - 93ms/epoch - 9ms/step
# Epoch 44/100000
# 10/10 - 0s - loss: 9.1719 - val_loss: 9.3656 - 58ms/epoch - 6ms/step
# Epoch 45/100000
# 10/10 - 0s - loss: 9.0986 - val_loss: 9.3020 - 40ms/epoch - 4ms/step
# Epoch 46/100000
# 10/10 - 0s - loss: 9.0893 - val_loss: 9.2487 - 41ms/epoch - 4ms/step
# Epoch 47/100000
# 10/10 - 0s - loss: 9.0265 - val_loss: 9.4995 - 42ms/epoch - 4ms/step
# Epoch 48/100000
# 10/10 - 0s - loss: 8.9921 - val_loss: 9.3708 - 42ms/epoch - 4ms/step
# Epoch 49/100000
# 10/10 - 0s - loss: 9.2186 - val_loss: 9.2332 - 41ms/epoch - 4ms/step
# Epoch 50/100000
# 10/10 - 0s - loss: 8.8648 - val_loss: 9.0442 - 42ms/epoch - 4ms/step
# Epoch 51/100000
# 10/10 - 0s - loss: 8.9971 - val_loss: 9.2697 - 39ms/epoch - 4ms/step
# Epoch 52/100000
# 10/10 - 0s - loss: 8.8762 - val_loss: 9.2449 - 43ms/epoch - 4ms/step
# Epoch 53/100000
# 10/10 - 0s - loss: 8.8778 - val_loss: 8.8825 - 41ms/epoch - 4ms/step
# Epoch 54/100000
# 10/10 - 0s - loss: 8.8443 - val_loss: 8.8309 - 41ms/epoch - 4ms/step
# Epoch 55/100000
# 10/10 - 0s - loss: 8.6236 - val_loss: 9.0328 - 41ms/epoch - 4ms/step
# Epoch 56/100000
# 10/10 - 0s - loss: 8.8568 - val_loss: 8.8617 - 42ms/epoch - 4ms/step
# Epoch 57/100000
# 10/10 - 0s - loss: 9.0310 - val_loss: 8.9873 - 41ms/epoch - 4ms/step
# Epoch 58/100000
# 10/10 - 0s - loss: 8.8294 - val_loss: 8.7270 - 42ms/epoch - 4ms/step
# Epoch 59/100000
# 10/10 - 0s - loss: 8.5595 - val_loss: 8.6420 - 40ms/epoch - 4ms/step
# Epoch 60/100000
# 10/10 - 0s - loss: 8.4746 - val_loss: 8.5932 - 44ms/epoch - 4ms/step
# Epoch 61/100000
# 10/10 - 0s - loss: 8.4784 - val_loss: 8.6460 - 41ms/epoch - 4ms/step
# Epoch 62/100000
# 10/10 - 0s - loss: 8.3806 - val_loss: 8.5068 - 40ms/epoch - 4ms/step
# Epoch 63/100000
# 10/10 - 0s - loss: 8.3891 - val_loss: 8.5185 - 42ms/epoch - 4ms/step
# Epoch 64/100000
# 10/10 - 0s - loss: 8.3347 - val_loss: 8.4776 - 40ms/epoch - 4ms/step
# Epoch 65/100000
# 10/10 - 0s - loss: 8.4434 - val_loss: 8.8308 - 39ms/epoch - 4ms/step
# Epoch 66/100000
# 10/10 - 0s - loss: 8.5161 - val_loss: 8.8755 - 41ms/epoch - 4ms/step
# Epoch 67/100000
# 10/10 - 0s - loss: 8.3595 - val_loss: 8.4331 - 41ms/epoch - 4ms/step
# Epoch 68/100000
# 10/10 - 0s - loss: 8.3907 - val_loss: 8.3270 - 76ms/epoch - 8ms/step
# Epoch 69/100000
# 10/10 - 0s - loss: 8.2059 - val_loss: 8.2722 - 41ms/epoch - 4ms/step
# Epoch 70/100000
# 10/10 - 0s - loss: 8.2699 - val_loss: 8.2643 - 44ms/epoch - 4ms/step
# Epoch 71/100000
# 10/10 - 0s - loss: 8.2535 - val_loss: 8.3221 - 42ms/epoch - 4ms/step
# Epoch 72/100000
# 10/10 - 0s - loss: 8.5253 - val_loss: 8.2060 - 43ms/epoch - 4ms/step
# Epoch 73/100000
# 10/10 - 0s - loss: 8.2534 - val_loss: 8.4733 - 39ms/epoch - 4ms/step
# Epoch 74/100000
# 10/10 - 0s - loss: 8.0714 - val_loss: 8.2215 - 41ms/epoch - 4ms/step
# Epoch 75/100000
# 10/10 - 0s - loss: 8.0000 - val_loss: 8.1422 - 44ms/epoch - 4ms/step
# Epoch 76/100000
# 10/10 - 0s - loss: 8.1571 - val_loss: 8.2001 - 40ms/epoch - 4ms/step
# Epoch 77/100000
# 10/10 - 0s - loss: 7.9678 - val_loss: 8.0333 - 39ms/epoch - 4ms/step
# Epoch 78/100000
# 10/10 - 0s - loss: 7.9553 - val_loss: 8.1816 - 41ms/epoch - 4ms/step
# Epoch 79/100000
# 10/10 - 0s - loss: 7.9349 - val_loss: 7.9686 - 40ms/epoch - 4ms/step
# Epoch 80/100000
# 10/10 - 0s - loss: 8.1224 - val_loss: 7.9742 - 41ms/epoch - 4ms/step
# Epoch 81/100000
# 10/10 - 0s - loss: 8.0024 - val_loss: 7.9536 - 39ms/epoch - 4ms/step
# Epoch 82/100000
# 10/10 - 0s - loss: 7.8966 - val_loss: 7.8729 - 41ms/epoch - 4ms/step
# Epoch 83/100000
# 10/10 - 0s - loss: 7.7726 - val_loss: 8.0259 - 40ms/epoch - 4ms/step
# Epoch 84/100000
# 10/10 - 0s - loss: 7.7636 - val_loss: 8.6217 - 41ms/epoch - 4ms/step
# Epoch 85/100000
# 10/10 - 0s - loss: 8.1491 - val_loss: 8.4482 - 40ms/epoch - 4ms/step
# Epoch 86/100000
# 10/10 - 0s - loss: 7.9346 - val_loss: 7.8145 - 41ms/epoch - 4ms/step
# Epoch 87/100000
# 10/10 - 0s - loss: 7.5893 - val_loss: 7.7486 - 40ms/epoch - 4ms/step
# Epoch 88/100000
# 10/10 - 0s - loss: 7.6703 - val_loss: 7.9224 - 41ms/epoch - 4ms/step
# Epoch 89/100000
# 10/10 - 0s - loss: 7.7043 - val_loss: 7.6724 - 43ms/epoch - 4ms/step
# Epoch 90/100000
# 10/10 - 0s - loss: 7.8904 - val_loss: 7.6253 - 40ms/epoch - 4ms/step
# Epoch 91/100000
# 10/10 - 0s - loss: 7.6170 - val_loss: 8.0225 - 41ms/epoch - 4ms/step
# Epoch 92/100000
# 10/10 - 0s - loss: 7.6112 - val_loss: 7.8631 - 40ms/epoch - 4ms/step
# Epoch 93/100000
# 10/10 - 0s - loss: 7.4694 - val_loss: 7.6789 - 41ms/epoch - 4ms/step
# Epoch 94/100000
# 10/10 - 0s - loss: 7.3553 - val_loss: 7.5223 - 39ms/epoch - 4ms/step
# Epoch 95/100000
# 10/10 - 0s - loss: 7.4362 - val_loss: 7.5930 - 40ms/epoch - 4ms/step
# Epoch 96/100000
# 10/10 - 0s - loss: 7.5673 - val_loss: 7.4894 - 39ms/epoch - 4ms/step
# Epoch 97/100000
# 10/10 - 0s - loss: 7.3783 - val_loss: 7.4199 - 40ms/epoch - 4ms/step
# Epoch 98/100000
# 10/10 - 0s - loss: 7.3307 - val_loss: 7.4143 - 41ms/epoch - 4ms/step
# Epoch 99/100000
# 10/10 - 0s - loss: 7.2836 - val_loss: 7.3489 - 41ms/epoch - 4ms/step
# Epoch 100/100000
# 10/10 - 0s - loss: 7.2583 - val_loss: 7.3090 - 41ms/epoch - 4ms/step
# Epoch 101/100000
# 10/10 - 0s - loss: 7.2653 - val_loss: 7.3323 - 43ms/epoch - 4ms/step
# Epoch 102/100000
# 10/10 - 0s - loss: 7.1856 - val_loss: 7.3419 - 40ms/epoch - 4ms/step
# Epoch 103/100000
# 10/10 - 0s - loss: 7.1378 - val_loss: 7.2276 - 41ms/epoch - 4ms/step
# Epoch 104/100000
# 10/10 - 0s - loss: 7.1791 - val_loss: 7.1988 - 41ms/epoch - 4ms/step
# Epoch 105/100000
# 10/10 - 0s - loss: 7.0781 - val_loss: 7.1562 - 42ms/epoch - 4ms/step
# Epoch 106/100000
# 10/10 - 0s - loss: 7.0076 - val_loss: 7.1531 - 39ms/epoch - 4ms/step
# Epoch 107/100000
# 10/10 - 0s - loss: 6.9914 - val_loss: 7.1468 - 40ms/epoch - 4ms/step
# Epoch 108/100000
# 10/10 - 0s - loss: 6.9898 - val_loss: 7.1294 - 39ms/epoch - 4ms/step
# Epoch 109/100000
# 10/10 - 0s - loss: 6.9867 - val_loss: 7.0465 - 40ms/epoch - 4ms/step
# Epoch 110/100000
# 10/10 - 0s - loss: 6.9018 - val_loss: 7.0153 - 41ms/epoch - 4ms/step
# Epoch 111/100000
# 10/10 - 0s - loss: 6.8236 - val_loss: 7.1112 - 43ms/epoch - 4ms/step
# Epoch 112/100000
# 10/10 - 0s - loss: 6.8274 - val_loss: 6.9586 - 42ms/epoch - 4ms/step
# Epoch 113/100000
# 10/10 - 0s - loss: 6.8928 - val_loss: 7.1248 - 42ms/epoch - 4ms/step
# Epoch 114/100000
# 10/10 - 0s - loss: 7.0446 - val_loss: 7.0565 - 41ms/epoch - 4ms/step
# Epoch 115/100000
# 10/10 - 0s - loss: 6.8474 - val_loss: 7.1064 - 41ms/epoch - 4ms/step
# Epoch 116/100000
# 10/10 - 0s - loss: 6.7329 - val_loss: 7.0281 - 40ms/epoch - 4ms/step
# Epoch 117/100000
# 10/10 - 0s - loss: 6.7205 - val_loss: 6.8703 - 42ms/epoch - 4ms/step
# Epoch 118/100000
# 10/10 - 0s - loss: 6.6397 - val_loss: 6.7798 - 41ms/epoch - 4ms/step
# Epoch 119/100000
# 10/10 - 0s - loss: 6.6471 - val_loss: 6.7577 - 41ms/epoch - 4ms/step
# Epoch 120/100000
# 10/10 - 0s - loss: 6.6612 - val_loss: 6.7172 - 41ms/epoch - 4ms/step
# Epoch 121/100000
# 10/10 - 0s - loss: 6.5512 - val_loss: 6.7445 - 40ms/epoch - 4ms/step
# Epoch 122/100000
# 10/10 - 0s - loss: 6.5948 - val_loss: 7.1572 - 39ms/epoch - 4ms/step
# Epoch 123/100000
# 10/10 - 0s - loss: 6.5534 - val_loss: 6.6685 - 40ms/epoch - 4ms/step
# Epoch 124/100000
# 10/10 - 0s - loss: 6.4781 - val_loss: 6.5978 - 42ms/epoch - 4ms/step
# Epoch 125/100000
# 10/10 - 0s - loss: 6.5003 - val_loss: 6.8323 - 39ms/epoch - 4ms/step
# Epoch 126/100000
# 10/10 - 0s - loss: 6.5389 - val_loss: 6.6273 - 41ms/epoch - 4ms/step
# Epoch 127/100000
# 10/10 - 0s - loss: 6.3887 - val_loss: 6.5907 - 42ms/epoch - 4ms/step
# Epoch 128/100000
# 10/10 - 0s - loss: 6.3778 - val_loss: 6.5012 - 44ms/epoch - 4ms/step
# Epoch 129/100000
# 10/10 - 0s - loss: 6.3504 - val_loss: 6.4534 - 41ms/epoch - 4ms/step
# Epoch 130/100000
# 10/10 - 0s - loss: 6.4043 - val_loss: 6.6113 - 41ms/epoch - 4ms/step
# Epoch 131/100000
# 10/10 - 0s - loss: 6.5852 - val_loss: 6.8899 - 39ms/epoch - 4ms/step
# Epoch 132/100000
# 10/10 - 0s - loss: 6.5386 - val_loss: 6.4183 - 39ms/epoch - 4ms/step
# Epoch 133/100000
# 10/10 - 0s - loss: 6.5055 - val_loss: 6.4116 - 41ms/epoch - 4ms/step
# Epoch 134/100000
# 10/10 - 0s - loss: 6.3241 - val_loss: 6.3600 - 40ms/epoch - 4ms/step
# Epoch 135/100000
# 10/10 - 0s - loss: 6.2389 - val_loss: 6.2821 - 39ms/epoch - 4ms/step
# Epoch 136/100000
# 10/10 - 0s - loss: 6.3861 - val_loss: 7.8226 - 40ms/epoch - 4ms/step
# Epoch 137/100000
# 10/10 - 0s - loss: 6.6734 - val_loss: 6.4489 - 40ms/epoch - 4ms/step
# Epoch 138/100000
# 10/10 - 0s - loss: 6.2265 - val_loss: 6.2612 - 39ms/epoch - 4ms/step
# Epoch 139/100000
# 10/10 - 0s - loss: 6.0995 - val_loss: 6.4451 - 40ms/epoch - 4ms/step
# Epoch 140/100000
# 10/10 - 0s - loss: 6.1083 - val_loss: 6.2148 - 40ms/epoch - 4ms/step
# Epoch 141/100000
# 10/10 - 0s - loss: 6.0608 - val_loss: 6.1596 - 43ms/epoch - 4ms/step
# Epoch 142/100000
# 10/10 - 0s - loss: 6.1336 - val_loss: 6.2167 - 42ms/epoch - 4ms/step
# Epoch 143/100000
# 10/10 - 0s - loss: 5.9674 - val_loss: 6.1683 - 42ms/epoch - 4ms/step
# Epoch 144/100000
# 10/10 - 0s - loss: 6.1207 - val_loss: 6.0371 - 42ms/epoch - 4ms/step
# Epoch 145/100000
# 10/10 - 0s - loss: 6.0670 - val_loss: 6.0473 - 41ms/epoch - 4ms/step
# Epoch 146/100000
# 10/10 - 0s - loss: 5.9136 - val_loss: 6.4407 - 43ms/epoch - 4ms/step
# Epoch 147/100000
# 10/10 - 0s - loss: 6.0958 - val_loss: 6.2660 - 41ms/epoch - 4ms/step
# Epoch 148/100000
# 10/10 - 0s - loss: 5.9250 - val_loss: 5.9429 - 41ms/epoch - 4ms/step
# Epoch 149/100000
# 10/10 - 0s - loss: 5.8476 - val_loss: 6.0359 - 41ms/epoch - 4ms/step
# Epoch 150/100000
# 10/10 - 0s - loss: 5.8699 - val_loss: 6.0410 - 41ms/epoch - 4ms/step
# Epoch 151/100000
# 10/10 - 0s - loss: 5.7439 - val_loss: 5.9477 - 42ms/epoch - 4ms/step
# Epoch 152/100000
# 10/10 - 0s - loss: 5.7335 - val_loss: 6.2523 - 42ms/epoch - 4ms/step
# Epoch 153/100000
# 10/10 - 0s - loss: 5.8706 - val_loss: 5.9613 - 41ms/epoch - 4ms/step
# Epoch 154/100000
# 10/10 - 0s - loss: 5.6584 - val_loss: 6.1097 - 42ms/epoch - 4ms/step
# Epoch 155/100000
# 10/10 - 0s - loss: 5.7690 - val_loss: 5.7486 - 40ms/epoch - 4ms/step
# Epoch 156/100000
# 10/10 - 0s - loss: 5.6807 - val_loss: 5.7388 - 39ms/epoch - 4ms/step
# Epoch 157/100000
# 10/10 - 0s - loss: 5.5838 - val_loss: 6.1973 - 42ms/epoch - 4ms/step
# Epoch 158/100000
# 10/10 - 0s - loss: 5.6417 - val_loss: 5.6630 - 42ms/epoch - 4ms/step
# Epoch 159/100000
# 10/10 - 0s - loss: 5.5755 - val_loss: 5.6394 - 41ms/epoch - 4ms/step
# Epoch 160/100000
# 10/10 - 0s - loss: 5.5121 - val_loss: 5.7084 - 42ms/epoch - 4ms/step
# Epoch 161/100000
# 10/10 - 0s - loss: 5.5975 - val_loss: 5.7396 - 41ms/epoch - 4ms/step
# Epoch 162/100000
# 10/10 - 0s - loss: 5.6816 - val_loss: 5.8745 - 42ms/epoch - 4ms/step
# Epoch 163/100000
# 10/10 - 0s - loss: 5.7409 - val_loss: 5.5536 - 41ms/epoch - 4ms/step
# Epoch 164/100000
# 10/10 - 0s - loss: 5.4775 - val_loss: 5.7262 - 41ms/epoch - 4ms/step
# Epoch 165/100000
# 10/10 - 0s - loss: 5.5204 - val_loss: 5.5298 - 42ms/epoch - 4ms/step
# Epoch 166/100000
# 10/10 - 0s - loss: 5.4924 - val_loss: 5.5064 - 39ms/epoch - 4ms/step
# Epoch 167/100000
# 10/10 - 0s - loss: 5.3396 - val_loss: 5.5430 - 41ms/epoch - 4ms/step
# Epoch 168/100000
# 10/10 - 0s - loss: 5.3314 - val_loss: 5.4759 - 39ms/epoch - 4ms/step
# Epoch 169/100000
# 10/10 - 0s - loss: 5.3885 - val_loss: 5.4349 - 41ms/epoch - 4ms/step
# Epoch 170/100000
# 10/10 - 0s - loss: 5.5855 - val_loss: 6.6066 - 41ms/epoch - 4ms/step
# Epoch 171/100000
# 10/10 - 0s - loss: 5.7550 - val_loss: 5.3719 - 43ms/epoch - 4ms/step
# Epoch 172/100000
# 10/10 - 0s - loss: 5.5573 - val_loss: 5.9146 - 42ms/epoch - 4ms/step
# Epoch 173/100000
# 10/10 - 0s - loss: 5.3996 - val_loss: 5.3305 - 43ms/epoch - 4ms/step
# Epoch 174/100000
# 10/10 - 0s - loss: 5.2015 - val_loss: 5.2971 - 45ms/epoch - 4ms/step
# Epoch 175/100000
# 10/10 - 0s - loss: 5.2582 - val_loss: 5.4332 - 42ms/epoch - 4ms/step
# Epoch 176/100000
# 10/10 - 0s - loss: 5.2713 - val_loss: 5.2648 - 43ms/epoch - 4ms/step
# Epoch 177/100000
# 10/10 - 0s - loss: 5.2342 - val_loss: 5.6470 - 42ms/epoch - 4ms/step
# Epoch 178/100000
# 10/10 - 0s - loss: 5.2964 - val_loss: 5.2275 - 41ms/epoch - 4ms/step
# Epoch 179/100000
# 10/10 - 0s - loss: 5.0927 - val_loss: 5.2780 - 43ms/epoch - 4ms/step
# Epoch 180/100000
# 10/10 - 0s - loss: 5.0838 - val_loss: 5.2349 - 43ms/epoch - 4ms/step
# Epoch 181/100000
# 10/10 - 0s - loss: 5.0311 - val_loss: 5.3844 - 43ms/epoch - 4ms/step
# Epoch 182/100000
# 10/10 - 0s - loss: 5.1257 - val_loss: 5.3018 - 43ms/epoch - 4ms/step
# Epoch 183/100000
# 10/10 - 0s - loss: 5.1893 - val_loss: 5.1283 - 55ms/epoch - 5ms/step
# Epoch 184/100000
# 10/10 - 0s - loss: 5.0255 - val_loss: 5.1376 - 52ms/epoch - 5ms/step
# Epoch 185/100000
# 10/10 - 0s - loss: 4.9567 - val_loss: 5.1398 - 45ms/epoch - 4ms/step
# Epoch 186/100000
# 10/10 - 0s - loss: 4.9354 - val_loss: 5.0469 - 46ms/epoch - 5ms/step
# Epoch 187/100000
# 10/10 - 0s - loss: 5.0892 - val_loss: 5.4284 - 44ms/epoch - 4ms/step
# Epoch 188/100000
# 10/10 - 0s - loss: 4.9861 - val_loss: 5.0231 - 41ms/epoch - 4ms/step
# Epoch 189/100000
# 10/10 - 0s - loss: 4.8892 - val_loss: 5.3396 - 41ms/epoch - 4ms/step
# Epoch 190/100000
# 10/10 - 0s - loss: 5.0737 - val_loss: 4.9652 - 42ms/epoch - 4ms/step
# Epoch 191/100000
# 10/10 - 0s - loss: 4.9745 - val_loss: 5.0322 - 43ms/epoch - 4ms/step
# Epoch 192/100000
# 10/10 - 0s - loss: 4.8330 - val_loss: 4.9506 - 43ms/epoch - 4ms/step
# Epoch 193/100000
# 10/10 - 0s - loss: 4.8586 - val_loss: 5.0860 - 41ms/epoch - 4ms/step
# Epoch 194/100000
# 10/10 - 0s - loss: 4.9873 - val_loss: 4.9615 - 42ms/epoch - 4ms/step
# Epoch 195/100000
# 10/10 - 0s - loss: 5.0168 - val_loss: 4.8891 - 40ms/epoch - 4ms/step
# Epoch 196/100000
# 10/10 - 0s - loss: 4.7435 - val_loss: 5.2385 - 44ms/epoch - 4ms/step
# Epoch 197/100000
# 10/10 - 0s - loss: 4.8220 - val_loss: 4.8925 - 45ms/epoch - 5ms/step
# Epoch 198/100000
# 10/10 - 0s - loss: 4.7726 - val_loss: 4.8445 - 49ms/epoch - 5ms/step
# Epoch 199/100000
# 10/10 - 0s - loss: 5.0023 - val_loss: 5.0649 - 39ms/epoch - 4ms/step
# Epoch 200/100000
# 10/10 - 0s - loss: 4.9217 - val_loss: 4.8051 - 41ms/epoch - 4ms/step
# Epoch 201/100000
# 10/10 - 0s - loss: 4.7281 - val_loss: 5.5949 - 43ms/epoch - 4ms/step
# Epoch 202/100000
# 10/10 - 0s - loss: 4.9429 - val_loss: 4.9724 - 40ms/epoch - 4ms/step
# Epoch 203/100000
# 10/10 - 0s - loss: 4.7914 - val_loss: 4.7718 - 40ms/epoch - 4ms/step
# Epoch 204/100000
# 10/10 - 0s - loss: 4.8313 - val_loss: 4.8706 - 42ms/epoch - 4ms/step
# Epoch 205/100000
# 10/10 - 0s - loss: 4.9404 - val_loss: 4.7360 - 41ms/epoch - 4ms/step
# Epoch 206/100000
# 10/10 - 0s - loss: 4.6891 - val_loss: 4.9204 - 43ms/epoch - 4ms/step
# Epoch 207/100000
# 10/10 - 0s - loss: 4.6968 - val_loss: 4.7382 - 42ms/epoch - 4ms/step
# Epoch 208/100000
# 10/10 - 0s - loss: 4.6406 - val_loss: 4.6681 - 40ms/epoch - 4ms/step
# Epoch 209/100000
# 10/10 - 0s - loss: 4.5887 - val_loss: 4.6970 - 41ms/epoch - 4ms/step
# Epoch 210/100000
# 10/10 - 0s - loss: 4.8059 - val_loss: 4.8185 - 43ms/epoch - 4ms/step
# Epoch 211/100000
# 10/10 - 0s - loss: 4.6285 - val_loss: 4.7735 - 39ms/epoch - 4ms/step
# Epoch 212/100000
# 10/10 - 0s - loss: 4.5654 - val_loss: 4.6623 - 44ms/epoch - 4ms/step
# Epoch 213/100000
# 10/10 - 0s - loss: 4.6158 - val_loss: 4.9709 - 43ms/epoch - 4ms/step
# Epoch 214/100000
# 10/10 - 0s - loss: 4.9804 - val_loss: 4.7083 - 41ms/epoch - 4ms/step
# Epoch 215/100000
# 10/10 - 0s - loss: 4.7663 - val_loss: 4.5922 - 44ms/epoch - 4ms/step
# Epoch 216/100000
# 10/10 - 0s - loss: 4.5854 - val_loss: 4.7145 - 42ms/epoch - 4ms/step
# Epoch 217/100000
# 10/10 - 0s - loss: 4.5705 - val_loss: 4.6855 - 41ms/epoch - 4ms/step
# Epoch 218/100000
# 10/10 - 0s - loss: 4.5740 - val_loss: 4.5592 - 44ms/epoch - 4ms/step
# Epoch 219/100000
# 10/10 - 0s - loss: 4.4722 - val_loss: 4.6923 - 43ms/epoch - 4ms/step
# Epoch 220/100000
# 10/10 - 0s - loss: 4.5936 - val_loss: 4.6397 - 39ms/epoch - 4ms/step
# Epoch 221/100000
# 10/10 - 0s - loss: 4.5232 - val_loss: 4.5146 - 41ms/epoch - 4ms/step
# Epoch 222/100000
# 10/10 - 0s - loss: 4.4242 - val_loss: 4.5586 - 42ms/epoch - 4ms/step
# Epoch 223/100000
# 10/10 - 0s - loss: 4.6360 - val_loss: 5.2695 - 39ms/epoch - 4ms/step
# Epoch 224/100000
# 10/10 - 0s - loss: 4.9413 - val_loss: 4.9174 - 43ms/epoch - 4ms/step
# Epoch 225/100000
# 10/10 - 0s - loss: 4.5377 - val_loss: 4.5435 - 40ms/epoch - 4ms/step
# Epoch 226/100000
# 10/10 - 0s - loss: 4.3957 - val_loss: 4.4692 - 43ms/epoch - 4ms/step
# Epoch 227/100000
# 10/10 - 0s - loss: 4.5378 - val_loss: 4.8518 - 42ms/epoch - 4ms/step
# Epoch 228/100000
# 10/10 - 0s - loss: 4.6602 - val_loss: 4.7363 - 41ms/epoch - 4ms/step
# Epoch 229/100000
# 10/10 - 0s - loss: 4.5535 - val_loss: 4.4539 - 44ms/epoch - 4ms/step
# Epoch 230/100000
# 10/10 - 0s - loss: 4.4802 - val_loss: 4.5474 - 43ms/epoch - 4ms/step
# Epoch 231/100000
# 10/10 - 0s - loss: 4.3745 - val_loss: 4.6723 - 42ms/epoch - 4ms/step
# Epoch 232/100000
# 10/10 - 0s - loss: 4.4207 - val_loss: 4.4329 - 42ms/epoch - 4ms/step
# Epoch 233/100000
# 10/10 - 0s - loss: 4.3635 - val_loss: 5.2497 - 45ms/epoch - 4ms/step
# Epoch 234/100000
# 10/10 - 0s - loss: 4.5084 - val_loss: 4.8077 - 43ms/epoch - 4ms/step
# Epoch 235/100000
# 10/10 - 0s - loss: 4.5742 - val_loss: 5.7615 - 42ms/epoch - 4ms/step
# Epoch 236/100000
# 10/10 - 0s - loss: 4.4976 - val_loss: 4.4086 - 43ms/epoch - 4ms/step
# Epoch 237/100000
# 10/10 - 0s - loss: 4.4091 - val_loss: 4.3947 - 42ms/epoch - 4ms/step
# Epoch 238/100000
# 10/10 - 0s - loss: 4.5653 - val_loss: 4.7119 - 43ms/epoch - 4ms/step
# Epoch 239/100000
# 10/10 - 0s - loss: 4.3145 - val_loss: 4.3458 - 39ms/epoch - 4ms/step
# Epoch 240/100000
# 10/10 - 0s - loss: 4.3695 - val_loss: 4.7941 - 40ms/epoch - 4ms/step
# Epoch 241/100000
# 10/10 - 0s - loss: 4.6452 - val_loss: 4.3679 - 42ms/epoch - 4ms/step
# Epoch 242/100000
# 10/10 - 0s - loss: 4.2489 - val_loss: 4.4889 - 42ms/epoch - 4ms/step
# Epoch 243/100000
# 10/10 - 0s - loss: 4.4408 - val_loss: 4.9941 - 43ms/epoch - 4ms/step
# Epoch 244/100000
# 10/10 - 0s - loss: 4.6739 - val_loss: 4.3369 - 41ms/epoch - 4ms/step
# Epoch 245/100000
# 10/10 - 0s - loss: 4.6129 - val_loss: 4.6854 - 42ms/epoch - 4ms/step
# Epoch 246/100000
# 10/10 - 0s - loss: 4.4280 - val_loss: 4.4106 - 43ms/epoch - 4ms/step
# Epoch 247/100000
# 10/10 - 0s - loss: 4.4013 - val_loss: 4.3455 - 44ms/epoch - 4ms/step
# Epoch 248/100000
# 10/10 - 0s - loss: 4.6020 - val_loss: 4.6223 - 47ms/epoch - 5ms/step
# Epoch 249/100000
# 10/10 - 0s - loss: 4.4083 - val_loss: 4.3462 - 42ms/epoch - 4ms/step
# Epoch 250/100000
# 10/10 - 0s - loss: 4.1784 - val_loss: 4.3334 - 39ms/epoch - 4ms/step
# Epoch 251/100000
# 10/10 - 0s - loss: 4.1930 - val_loss: 4.2788 - 43ms/epoch - 4ms/step
# Epoch 252/100000
# 10/10 - 0s - loss: 4.2235 - val_loss: 4.2609 - 39ms/epoch - 4ms/step
# Epoch 253/100000
# 10/10 - 0s - loss: 4.3022 - val_loss: 4.4297 - 43ms/epoch - 4ms/step
# Epoch 254/100000
# 10/10 - 0s - loss: 4.3410 - val_loss: 4.2915 - 41ms/epoch - 4ms/step
# Epoch 255/100000
# 10/10 - 0s - loss: 4.1738 - val_loss: 4.2863 - 40ms/epoch - 4ms/step
# Epoch 256/100000
# 10/10 - 0s - loss: 4.2187 - val_loss: 4.2836 - 43ms/epoch - 4ms/step
# Epoch 257/100000
# 10/10 - 0s - loss: 4.3508 - val_loss: 4.9988 - 46ms/epoch - 5ms/step
# Epoch 258/100000
# 10/10 - 0s - loss: 4.3448 - val_loss: 4.2320 - 41ms/epoch - 4ms/step
# Epoch 259/100000
# 10/10 - 0s - loss: 4.6329 - val_loss: 5.2840 - 41ms/epoch - 4ms/step
# Epoch 260/100000
# 10/10 - 0s - loss: 4.5700 - val_loss: 5.0902 - 41ms/epoch - 4ms/step
# Epoch 261/100000
# 10/10 - 0s - loss: 4.2583 - val_loss: 4.2983 - 42ms/epoch - 4ms/step
# Epoch 262/100000
# 10/10 - 0s - loss: 4.3753 - val_loss: 4.3117 - 41ms/epoch - 4ms/step
# Epoch 263/100000
# 10/10 - 0s - loss: 4.1987 - val_loss: 4.2606 - 75ms/epoch - 7ms/step
# Epoch 264/100000
# 10/10 - 0s - loss: 4.1626 - val_loss: 4.5119 - 41ms/epoch - 4ms/step
# Epoch 265/100000
# 10/10 - 0s - loss: 4.2007 - val_loss: 4.1753 - 42ms/epoch - 4ms/step
# Epoch 266/100000
# 10/10 - 0s - loss: 4.1488 - val_loss: 4.3091 - 39ms/epoch - 4ms/step
# Epoch 267/100000
# 10/10 - 0s - loss: 4.1112 - val_loss: 4.1744 - 44ms/epoch - 4ms/step
# Epoch 268/100000
# 10/10 - 0s - loss: 4.3477 - val_loss: 4.1979 - 42ms/epoch - 4ms/step
# Epoch 269/100000
# 10/10 - 0s - loss: 4.1093 - val_loss: 4.1926 - 43ms/epoch - 4ms/step
# Epoch 270/100000
# 10/10 - 0s - loss: 4.1680 - val_loss: 4.3145 - 41ms/epoch - 4ms/step
# Epoch 271/100000
# 10/10 - 0s - loss: 4.3339 - val_loss: 4.3004 - 44ms/epoch - 4ms/step
# Epoch 272/100000
# 10/10 - 0s - loss: 4.3065 - val_loss: 4.1489 - 42ms/epoch - 4ms/step
# Epoch 273/100000
# 10/10 - 0s - loss: 4.4533 - val_loss: 4.3292 - 42ms/epoch - 4ms/step
# Epoch 274/100000
# 10/10 - 0s - loss: 4.6923 - val_loss: 4.2682 - 42ms/epoch - 4ms/step
# Epoch 275/100000
# 10/10 - 0s - loss: 4.4115 - val_loss: 4.2931 - 42ms/epoch - 4ms/step
# Epoch 276/100000
# 10/10 - 0s - loss: 4.2645 - val_loss: 4.6707 - 43ms/epoch - 4ms/step
# Epoch 277/100000
# 10/10 - 0s - loss: 4.1548 - val_loss: 4.7774 - 41ms/epoch - 4ms/step
# Epoch 278/100000
# 10/10 - 0s - loss: 4.2964 - val_loss: 4.4914 - 50ms/epoch - 5ms/step
# Epoch 279/100000
# 10/10 - 0s - loss: 4.4774 - val_loss: 4.9785 - 42ms/epoch - 4ms/step
# Epoch 280/100000
# 10/10 - 0s - loss: 4.6365 - val_loss: 4.2914 - 42ms/epoch - 4ms/step
# Epoch 281/100000
# 10/10 - 0s - loss: 4.2254 - val_loss: 4.1339 - 42ms/epoch - 4ms/step
# Epoch 282/100000
# 10/10 - 0s - loss: 4.1545 - val_loss: 4.1316 - 43ms/epoch - 4ms/step
# Epoch 283/100000
# 10/10 - 0s - loss: 4.5584 - val_loss: 5.9661 - 44ms/epoch - 4ms/step
# Epoch 284/100000
# 10/10 - 0s - loss: 4.2756 - val_loss: 4.1309 - 42ms/epoch - 4ms/step
# Epoch 285/100000
# 10/10 - 0s - loss: 4.1174 - val_loss: 4.7020 - 44ms/epoch - 4ms/step
# Epoch 286/100000
# 10/10 - 0s - loss: 4.3192 - val_loss: 4.7683 - 43ms/epoch - 4ms/step
# Epoch 287/100000
# 10/10 - 0s - loss: 4.2498 - val_loss: 4.1057 - 40ms/epoch - 4ms/step
# Epoch 288/100000
# 10/10 - 0s - loss: 4.0825 - val_loss: 4.4186 - 45ms/epoch - 5ms/step
# Epoch 289/100000
# 10/10 - 0s - loss: 4.4602 - val_loss: 4.8009 - 41ms/epoch - 4ms/step
# Epoch 290/100000
# 10/10 - 0s - loss: 4.2897 - val_loss: 4.0965 - 44ms/epoch - 4ms/step
# Epoch 291/100000
# 10/10 - 0s - loss: 4.1000 - val_loss: 4.4782 - 43ms/epoch - 4ms/step
# Epoch 292/100000
# 10/10 - 0s - loss: 4.1186 - val_loss: 4.2386 - 42ms/epoch - 4ms/step
# Epoch 293/100000
# 10/10 - 0s - loss: 4.2401 - val_loss: 4.8936 - 41ms/epoch - 4ms/step
# Epoch 294/100000
# 10/10 - 0s - loss: 4.1620 - val_loss: 4.3133 - 44ms/epoch - 4ms/step
# Epoch 295/100000
# 10/10 - 0s - loss: 4.0849 - val_loss: 4.1541 - 39ms/epoch - 4ms/step
# Epoch 296/100000
# 10/10 - 0s - loss: 4.0557 - val_loss: 4.6158 - 43ms/epoch - 4ms/step
# Epoch 297/100000
# 10/10 - 0s - loss: 4.2025 - val_loss: 4.8070 - 42ms/epoch - 4ms/step
# Epoch 298/100000
# 10/10 - 0s - loss: 4.5535 - val_loss: 4.0752 - 43ms/epoch - 4ms/step
# Epoch 299/100000
# 10/10 - 0s - loss: 4.1914 - val_loss: 4.0998 - 42ms/epoch - 4ms/step
# Epoch 300/100000
# 10/10 - 0s - loss: 4.1136 - val_loss: 4.9700 - 43ms/epoch - 4ms/step
# Epoch 301/100000
# 10/10 - 0s - loss: 4.6789 - val_loss: 4.7637 - 41ms/epoch - 4ms/step
# Epoch 302/100000
# 10/10 - 0s - loss: 4.4904 - val_loss: 4.0738 - 44ms/epoch - 4ms/step
# Epoch 303/100000
# 10/10 - 0s - loss: 4.1710 - val_loss: 4.6343 - 41ms/epoch - 4ms/step
# Epoch 304/100000
# 10/10 - 0s - loss: 3.9824 - val_loss: 4.0801 - 42ms/epoch - 4ms/step
# Epoch 305/100000
# 10/10 - 0s - loss: 4.3142 - val_loss: 4.2852 - 44ms/epoch - 4ms/step
# Epoch 306/100000
# 10/10 - 0s - loss: 4.3186 - val_loss: 4.4281 - 42ms/epoch - 4ms/step
# Epoch 307/100000
# 10/10 - 0s - loss: 4.5445 - val_loss: 4.0741 - 42ms/epoch - 4ms/step
# Epoch 308/100000
# 10/10 - 0s - loss: 4.5497 - val_loss: 5.6161 - 44ms/epoch - 4ms/step
# Epoch 309/100000
# 10/10 - 0s - loss: 4.9742 - val_loss: 4.8203 - 41ms/epoch - 4ms/step
# Epoch 310/100000
# 10/10 - 0s - loss: 4.5893 - val_loss: 4.5289 - 43ms/epoch - 4ms/step
# Epoch 311/100000
# 10/10 - 0s - loss: 4.8813 - val_loss: 4.3332 - 41ms/epoch - 4ms/step
# Epoch 312/100000
# 10/10 - 0s - loss: 4.3180 - val_loss: 4.0532 - 41ms/epoch - 4ms/step
# Epoch 313/100000
# 10/10 - 0s - loss: 4.1045 - val_loss: 4.0690 - 42ms/epoch - 4ms/step
# Epoch 314/100000
# 10/10 - 0s - loss: 4.0199 - val_loss: 5.4086 - 39ms/epoch - 4ms/step
# Epoch 315/100000
# 10/10 - 0s - loss: 4.1884 - val_loss: 4.0597 - 42ms/epoch - 4ms/step
# Epoch 316/100000
# 10/10 - 0s - loss: 4.0957 - val_loss: 4.8178 - 41ms/epoch - 4ms/step
# Epoch 317/100000
# 10/10 - 0s - loss: 4.3200 - val_loss: 4.3798 - 41ms/epoch - 4ms/step
# Epoch 318/100000
# 10/10 - 0s - loss: 4.0191 - val_loss: 4.0547 - 39ms/epoch - 4ms/step
# Epoch 319/100000
# 10/10 - 0s - loss: 4.0805 - val_loss: 4.1118 - 40ms/epoch - 4ms/step
# Epoch 320/100000
# 10/10 - 0s - loss: 4.0466 - val_loss: 4.0343 - 45ms/epoch - 5ms/step
# Epoch 321/100000
# 10/10 - 0s - loss: 4.3101 - val_loss: 4.1497 - 40ms/epoch - 4ms/step
# Epoch 322/100000
# 10/10 - 0s - loss: 4.1055 - val_loss: 4.1215 - 42ms/epoch - 4ms/step
# Epoch 323/100000
# 10/10 - 0s - loss: 4.0491 - val_loss: 4.0301 - 42ms/epoch - 4ms/step
# Epoch 324/100000
# 10/10 - 0s - loss: 3.9781 - val_loss: 5.1594 - 41ms/epoch - 4ms/step
# Epoch 325/100000
# 10/10 - 0s - loss: 4.8199 - val_loss: 4.9398 - 43ms/epoch - 4ms/step
# Epoch 326/100000
# 10/10 - 0s - loss: 4.1829 - val_loss: 4.7600 - 38ms/epoch - 4ms/step
# Epoch 327/100000
# 10/10 - 0s - loss: 4.4347 - val_loss: 4.2689 - 41ms/epoch - 4ms/step
# Epoch 328/100000
# 10/10 - 0s - loss: 4.1472 - val_loss: 4.0345 - 44ms/epoch - 4ms/step
# Epoch 329/100000
# 10/10 - 0s - loss: 4.1731 - val_loss: 4.0563 - 43ms/epoch - 4ms/step
# Epoch 330/100000
# 10/10 - 0s - loss: 3.9283 - val_loss: 4.1008 - 40ms/epoch - 4ms/step
# Epoch 331/100000
# 10/10 - 0s - loss: 4.0771 - val_loss: 4.1970 - 41ms/epoch - 4ms/step
# Epoch 332/100000
# 10/10 - 0s - loss: 4.1053 - val_loss: 4.1691 - 42ms/epoch - 4ms/step
# Epoch 333/100000
# 10/10 - 0s - loss: 4.2041 - val_loss: 4.1822 - 42ms/epoch - 4ms/step
# Epoch 334/100000
# 10/10 - 0s - loss: 4.2406 - val_loss: 4.2947 - 40ms/epoch - 4ms/step
# Epoch 335/100000
# 10/10 - 0s - loss: 4.2684 - val_loss: 5.9691 - 43ms/epoch - 4ms/step
# Epoch 336/100000
# 10/10 - 0s - loss: 5.0811 - val_loss: 5.6734 - 41ms/epoch - 4ms/step
# Epoch 337/100000
# 10/10 - 0s - loss: 4.9067 - val_loss: 5.7986 - 39ms/epoch - 4ms/step
# Epoch 338/100000
# 10/10 - 0s - loss: 5.4746 - val_loss: 6.8457 - 43ms/epoch - 4ms/step
# Epoch 339/100000
# 10/10 - 0s - loss: 5.4828 - val_loss: 6.4250 - 40ms/epoch - 4ms/step
# Epoch 340/100000
# 10/10 - 0s - loss: 4.6290 - val_loss: 4.0793 - 42ms/epoch - 4ms/step
# Epoch 341/100000
# 10/10 - 0s - loss: 4.0024 - val_loss: 4.0486 - 44ms/epoch - 4ms/step
# Epoch 342/100000
# 10/10 - 0s - loss: 3.9976 - val_loss: 4.0123 - 53ms/epoch - 5ms/step
# Epoch 343/100000
# 10/10 - 0s - loss: 3.9253 - val_loss: 4.5149 - 41ms/epoch - 4ms/step
# Epoch 344/100000
# 10/10 - 0s - loss: 4.2289 - val_loss: 4.9296 - 40ms/epoch - 4ms/step
# Epoch 345/100000
# 10/10 - 0s - loss: 4.8528 - val_loss: 4.1185 - 42ms/epoch - 4ms/step
# Epoch 346/100000
# 10/10 - 0s - loss: 5.0930 - val_loss: 4.0272 - 43ms/epoch - 4ms/step
# Epoch 347/100000
# 10/10 - 0s - loss: 4.5308 - val_loss: 4.0928 - 43ms/epoch - 4ms/step
# Epoch 348/100000
# 10/10 - 0s - loss: 4.2528 - val_loss: 4.0234 - 69ms/epoch - 7ms/step
# Epoch 349/100000
# 10/10 - 0s - loss: 4.0157 - val_loss: 4.1462 - 43ms/epoch - 4ms/step
# Epoch 350/100000
# 10/10 - 0s - loss: 4.1322 - val_loss: 4.0572 - 41ms/epoch - 4ms/step
# Epoch 351/100000
# 10/10 - 0s - loss: 4.1152 - val_loss: 4.0177 - 46ms/epoch - 5ms/step
# Epoch 352/100000
# 10/10 - 0s - loss: 4.0464 - val_loss: 4.4040 - 43ms/epoch - 4ms/step
# Epoch 353/100000
# 10/10 - 0s - loss: 4.0368 - val_loss: 4.4461 - 48ms/epoch - 5ms/step
# Epoch 354/100000
# 10/10 - 0s - loss: 4.0558 - val_loss: 4.3825 - 49ms/epoch - 5ms/step
# Epoch 355/100000
# 10/10 - 0s - loss: 4.2625 - val_loss: 4.0167 - 41ms/epoch - 4ms/step
# Epoch 356/100000
# 10/10 - 0s - loss: 4.0595 - val_loss: 4.0159 - 39ms/epoch - 4ms/step
# Epoch 357/100000
# 10/10 - 0s - loss: 4.3878 - val_loss: 4.0310 - 41ms/epoch - 4ms/step
# Epoch 358/100000
# 10/10 - 0s - loss: 4.0443 - val_loss: 4.3328 - 41ms/epoch - 4ms/step
# Epoch 359/100000
# 10/10 - 0s - loss: 4.1966 - val_loss: 5.2851 - 43ms/epoch - 4ms/step
# Epoch 360/100000
# 10/10 - 0s - loss: 5.2798 - val_loss: 4.8679 - 40ms/epoch - 4ms/step
# Epoch 361/100000
# 10/10 - 0s - loss: 4.2460 - val_loss: 4.3768 - 40ms/epoch - 4ms/step
# Epoch 362/100000
# 10/10 - 0s - loss: 3.9224 - val_loss: 4.0248 - 41ms/epoch - 4ms/step
# Epoch 363/100000
# 10/10 - 0s - loss: 4.0951 - val_loss: 4.4155 - 43ms/epoch - 4ms/step
# Epoch 364/100000
# 10/10 - 0s - loss: 4.3127 - val_loss: 4.0685 - 41ms/epoch - 4ms/step
# Epoch 365/100000
# 10/10 - 0s - loss: 4.1046 - val_loss: 4.0016 - 41ms/epoch - 4ms/step
# Epoch 366/100000
# 10/10 - 0s - loss: 3.9436 - val_loss: 4.1368 - 41ms/epoch - 4ms/step
# Epoch 367/100000
# 10/10 - 0s - loss: 4.0669 - val_loss: 4.0028 - 41ms/epoch - 4ms/step
# Epoch 368/100000
# 10/10 - 0s - loss: 4.1468 - val_loss: 4.1024 - 39ms/epoch - 4ms/step
# Epoch 369/100000
# 10/10 - 0s - loss: 4.5557 - val_loss: 4.1588 - 42ms/epoch - 4ms/step
# Epoch 370/100000
# 10/10 - 0s - loss: 4.9476 - val_loss: 6.2746 - 41ms/epoch - 4ms/step
# Epoch 371/100000
# 10/10 - 0s - loss: 4.8874 - val_loss: 8.3848 - 39ms/epoch - 4ms/step
# Epoch 372/100000
# 10/10 - 0s - loss: 4.9868 - val_loss: 5.2167 - 45ms/epoch - 4ms/step
# Epoch 373/100000
# 10/10 - 0s - loss: 4.4837 - val_loss: 4.2227 - 43ms/epoch - 4ms/step
# Epoch 374/100000
# 10/10 - 0s - loss: 4.1056 - val_loss: 4.1538 - 39ms/epoch - 4ms/step
# Epoch 375/100000
# 10/10 - 0s - loss: 4.2237 - val_loss: 4.5793 - 41ms/epoch - 4ms/step
# Epoch 376/100000
# 10/10 - 0s - loss: 4.3189 - val_loss: 5.6299 - 44ms/epoch - 4ms/step
# Epoch 377/100000
# 10/10 - 0s - loss: 4.2940 - val_loss: 4.0838 - 40ms/epoch - 4ms/step
# Epoch 378/100000
# 10/10 - 0s - loss: 4.4709 - val_loss: 4.5775 - 41ms/epoch - 4ms/step
# Epoch 379/100000
# 10/10 - 0s - loss: 4.5375 - val_loss: 4.6392 - 40ms/epoch - 4ms/step
# Epoch 380/100000
# 10/10 - 0s - loss: 4.3902 - val_loss: 4.0226 - 40ms/epoch - 4ms/step
# Epoch 381/100000
# 10/10 - 0s - loss: 4.3894 - val_loss: 4.2542 - 39ms/epoch - 4ms/step
# Epoch 382/100000
# 10/10 - 0s - loss: 4.2061 - val_loss: 3.9863 - 39ms/epoch - 4ms/step
# Epoch 383/100000
# 10/10 - 0s - loss: 3.9614 - val_loss: 4.0006 - 46ms/epoch - 5ms/step
# Epoch 384/100000
# 10/10 - 0s - loss: 3.9218 - val_loss: 3.9974 - 40ms/epoch - 4ms/step
# Epoch 385/100000
# 10/10 - 0s - loss: 4.2732 - val_loss: 4.6745 - 41ms/epoch - 4ms/step
# Epoch 386/100000
# 10/10 - 0s - loss: 4.4895 - val_loss: 4.0713 - 41ms/epoch - 4ms/step
# Epoch 387/100000
# 10/10 - 0s - loss: 4.1772 - val_loss: 4.1718 - 41ms/epoch - 4ms/step
# Epoch 388/100000
# 10/10 - 0s - loss: 4.0419 - val_loss: 4.0352 - 40ms/epoch - 4ms/step
# Epoch 389/100000
# 10/10 - 0s - loss: 3.9581 - val_loss: 3.9939 - 41ms/epoch - 4ms/step
# Epoch 390/100000
# 10/10 - 0s - loss: 3.9964 - val_loss: 4.0547 - 41ms/epoch - 4ms/step
# Epoch 391/100000
# 10/10 - 0s - loss: 4.1016 - val_loss: 4.3367 - 41ms/epoch - 4ms/step
# Epoch 392/100000
# 10/10 - 0s - loss: 4.2679 - val_loss: 4.2457 - 41ms/epoch - 4ms/step
# Epoch 393/100000
# 10/10 - 0s - loss: 4.0299 - val_loss: 3.9836 - 38ms/epoch - 4ms/step
# Epoch 394/100000
# 10/10 - 0s - loss: 3.9160 - val_loss: 3.9830 - 40ms/epoch - 4ms/step
# Epoch 395/100000
# 10/10 - 0s - loss: 4.3337 - val_loss: 5.1482 - 41ms/epoch - 4ms/step
# Epoch 396/100000
# 10/10 - 0s - loss: 5.0383 - val_loss: 4.0728 - 40ms/epoch - 4ms/step
# Epoch 397/100000
# 10/10 - 0s - loss: 4.1564 - val_loss: 4.2072 - 40ms/epoch - 4ms/step
# Epoch 398/100000
# 10/10 - 0s - loss: 4.1316 - val_loss: 4.0215 - 42ms/epoch - 4ms/step
# Epoch 399/100000
# 10/10 - 0s - loss: 4.0628 - val_loss: 4.2531 - 41ms/epoch - 4ms/step
# Epoch 400/100000
# 10/10 - 0s - loss: 4.1996 - val_loss: 4.0015 - 43ms/epoch - 4ms/step
# Epoch 401/100000
# 10/10 - 0s - loss: 4.7545 - val_loss: 6.2303 - 41ms/epoch - 4ms/step
# Epoch 402/100000
# 10/10 - 0s - loss: 4.9926 - val_loss: 5.1608 - 41ms/epoch - 4ms/step
# Epoch 403/100000
# 10/10 - 0s - loss: 4.4350 - val_loss: 4.6985 - 40ms/epoch - 4ms/step
# Epoch 404/100000
# 10/10 - 0s - loss: 4.4375 - val_loss: 4.1041 - 40ms/epoch - 4ms/step
# Epoch 405/100000
# 10/10 - 0s - loss: 4.0211 - val_loss: 4.0587 - 41ms/epoch - 4ms/step
# Epoch 406/100000
# 10/10 - 0s - loss: 4.1644 - val_loss: 4.4001 - 40ms/epoch - 4ms/step
# Epoch 407/100000
# 10/10 - 0s - loss: 4.1003 - val_loss: 4.0007 - 41ms/epoch - 4ms/step
# Epoch 408/100000
# 10/10 - 0s - loss: 3.9104 - val_loss: 3.9977 - 41ms/epoch - 4ms/step
# Epoch 409/100000
# 10/10 - 0s - loss: 3.9913 - val_loss: 3.9952 - 42ms/epoch - 4ms/step
# Epoch 410/100000
# 10/10 - 0s - loss: 4.2606 - val_loss: 3.9777 - 39ms/epoch - 4ms/step
# Epoch 411/100000
# 10/10 - 0s - loss: 4.9047 - val_loss: 6.5696 - 40ms/epoch - 4ms/step
# Epoch 412/100000
# 10/10 - 0s - loss: 4.4608 - val_loss: 4.1164 - 40ms/epoch - 4ms/step
# Epoch 413/100000
# 10/10 - 0s - loss: 4.2385 - val_loss: 4.4468 - 40ms/epoch - 4ms/step
# Epoch 414/100000
# 10/10 - 0s - loss: 4.0534 - val_loss: 4.5181 - 41ms/epoch - 4ms/step
# Epoch 415/100000
# 10/10 - 0s - loss: 3.9856 - val_loss: 4.0483 - 40ms/epoch - 4ms/step
# Epoch 416/100000
# 10/10 - 0s - loss: 4.2617 - val_loss: 4.9597 - 41ms/epoch - 4ms/step
# Epoch 417/100000
# 10/10 - 0s - loss: 4.4538 - val_loss: 4.6537 - 41ms/epoch - 4ms/step
# Epoch 418/100000
# 10/10 - 0s - loss: 4.1423 - val_loss: 4.0747 - 39ms/epoch - 4ms/step
# Epoch 419/100000
# 10/10 - 0s - loss: 3.9102 - val_loss: 3.9888 - 42ms/epoch - 4ms/step
# Epoch 420/100000
# 10/10 - 0s - loss: 4.2854 - val_loss: 4.2954 - 43ms/epoch - 4ms/step
# Epoch 421/100000
# 10/10 - 0s - loss: 4.1743 - val_loss: 4.0107 - 42ms/epoch - 4ms/step
# Epoch 422/100000
# 10/10 - 0s - loss: 4.1513 - val_loss: 4.4247 - 40ms/epoch - 4ms/step
# Epoch 423/100000
# 10/10 - 0s - loss: 4.6899 - val_loss: 5.4238 - 40ms/epoch - 4ms/step
# Epoch 424/100000
# 10/10 - 0s - loss: 4.7226 - val_loss: 4.5637 - 42ms/epoch - 4ms/step
# Epoch 425/100000
# 10/10 - 0s - loss: 4.2283 - val_loss: 4.0719 - 40ms/epoch - 4ms/step
# Epoch 426/100000
# 10/10 - 0s - loss: 4.1019 - val_loss: 4.2308 - 42ms/epoch - 4ms/step
# Epoch 427/100000
# 10/10 - 0s - loss: 4.0730 - val_loss: 4.1942 - 41ms/epoch - 4ms/step
# Epoch 428/100000
# 10/10 - 0s - loss: 4.0080 - val_loss: 4.3120 - 41ms/epoch - 4ms/step
# Epoch 429/100000
# 10/10 - 0s - loss: 3.8863 - val_loss: 4.4399 - 41ms/epoch - 4ms/step
# Epoch 430/100000
# 10/10 - 0s - loss: 4.1529 - val_loss: 4.4342 - 40ms/epoch - 4ms/step
# Epoch 431/100000
# 10/10 - 0s - loss: 4.2504 - val_loss: 4.0369 - 41ms/epoch - 4ms/step
# Epoch 432/100000
# 10/10 - 0s - loss: 4.1143 - val_loss: 4.0313 - 39ms/epoch - 4ms/step
# Epoch 433/100000
# 10/10 - 0s - loss: 3.8940 - val_loss: 4.1586 - 41ms/epoch - 4ms/step
# Epoch 434/100000
# 10/10 - 0s - loss: 4.0859 - val_loss: 4.6205 - 40ms/epoch - 4ms/step
# Epoch 435/100000
# 10/10 - 0s - loss: 4.0494 - val_loss: 4.7768 - 42ms/epoch - 4ms/step
# Epoch 436/100000
# 10/10 - 0s - loss: 4.2858 - val_loss: 5.1372 - 41ms/epoch - 4ms/step
# Epoch 437/100000
# 10/10 - 0s - loss: 4.8201 - val_loss: 4.0657 - 40ms/epoch - 4ms/step
# Epoch 438/100000
# 10/10 - 0s - loss: 3.9249 - val_loss: 3.9898 - 42ms/epoch - 4ms/step
# Epoch 439/100000
# 10/10 - 0s - loss: 3.9805 - val_loss: 4.2019 - 39ms/epoch - 4ms/step
# Epoch 440/100000
# 10/10 - 0s - loss: 4.1455 - val_loss: 5.0921 - 41ms/epoch - 4ms/step
# Epoch 441/100000
# 10/10 - 0s - loss: 4.2274 - val_loss: 4.1995 - 38ms/epoch - 4ms/step
# Epoch 442/100000
# 10/10 - 0s - loss: 5.1265 - val_loss: 4.5256 - 41ms/epoch - 4ms/step
# Epoch 443/100000
# 10/10 - 0s - loss: 7.1089 - val_loss: 4.3669 - 40ms/epoch - 4ms/step
# Epoch 444/100000
# 10/10 - 0s - loss: 6.3776 - val_loss: 5.0633 - 41ms/epoch - 4ms/step
# Epoch 445/100000
# 10/10 - 0s - loss: 5.2091 - val_loss: 4.2095 - 42ms/epoch - 4ms/step
# Epoch 446/100000
# 10/10 - 0s - loss: 4.1511 - val_loss: 3.9943 - 41ms/epoch - 4ms/step
# Epoch 447/100000
# 10/10 - 0s - loss: 5.1609 - val_loss: 5.2121 - 43ms/epoch - 4ms/step
# Epoch 448/100000
# 10/10 - 0s - loss: 4.5714 - val_loss: 4.6913 - 40ms/epoch - 4ms/step
# Epoch 449/100000
# 10/10 - 0s - loss: 4.5842 - val_loss: 4.6740 - 43ms/epoch - 4ms/step
# Epoch 450/100000
# 10/10 - 0s - loss: 4.6622 - val_loss: 4.2513 - 40ms/epoch - 4ms/step
# Epoch 451/100000
# 10/10 - 0s - loss: 5.0754 - val_loss: 4.0279 - 41ms/epoch - 4ms/step
# Epoch 452/100000
# 10/10 - 0s - loss: 4.6318 - val_loss: 3.9838 - 41ms/epoch - 4ms/step
# Epoch 453/100000
# 10/10 - 0s - loss: 4.4048 - val_loss: 4.3088 - 41ms/epoch - 4ms/step
# Epoch 454/100000
# 10/10 - 0s - loss: 4.5138 - val_loss: 3.9866 - 41ms/epoch - 4ms/step
# Epoch 455/100000
# 10/10 - 0s - loss: 4.9684 - val_loss: 4.4181 - 41ms/epoch - 4ms/step
# Epoch 456/100000
# 10/10 - 0s - loss: 4.4748 - val_loss: 5.2131 - 40ms/epoch - 4ms/step
# Epoch 457/100000
# 10/10 - 0s - loss: 5.4099 - val_loss: 4.2433 - 40ms/epoch - 4ms/step
# Epoch 458/100000
# 10/10 - 0s - loss: 4.9355 - val_loss: 4.0060 - 40ms/epoch - 4ms/step
# Epoch 459/100000
# 10/10 - 0s - loss: 4.5878 - val_loss: 3.9932 - 41ms/epoch - 4ms/step
# Epoch 460/100000
# 10/10 - 0s - loss: 4.0680 - val_loss: 4.0005 - 40ms/epoch - 4ms/step
# Epoch 461/100000
# 10/10 - 0s - loss: 4.0461 - val_loss: 4.1275 - 41ms/epoch - 4ms/step
# Epoch 462/100000
# 10/10 - 0s - loss: 4.2644 - val_loss: 4.5582 - 41ms/epoch - 4ms/step
# Epoch 463/100000
# 10/10 - 0s - loss: 3.9246 - val_loss: 4.0646 - 39ms/epoch - 4ms/step
# Epoch 464/100000
# 10/10 - 0s - loss: 4.5981 - val_loss: 4.8954 - 42ms/epoch - 4ms/step
# Epoch 465/100000
# 10/10 - 0s - loss: 5.6850 - val_loss: 4.1368 - 40ms/epoch - 4ms/step
# Epoch 466/100000
# 10/10 - 0s - loss: 5.4194 - val_loss: 8.2661 - 41ms/epoch - 4ms/step
# Epoch 467/100000
# 10/10 - 0s - loss: 7.3907 - val_loss: 13.9064 - 64ms/epoch - 6ms/step
# Epoch 468/100000
# 10/10 - 0s - loss: 9.4682 - val_loss: 9.0481 - 41ms/epoch - 4ms/step
# Epoch 469/100000
# 10/10 - 0s - loss: 7.9788 - val_loss: 6.2717 - 41ms/epoch - 4ms/step
# Epoch 470/100000
# 10/10 - 0s - loss: 5.3109 - val_loss: 4.7598 - 43ms/epoch - 4ms/step
# Epoch 471/100000
# 10/10 - 0s - loss: 4.2795 - val_loss: 4.7794 - 43ms/epoch - 4ms/step
# Epoch 472/100000
# 10/10 - 0s - loss: 4.0256 - val_loss: 4.1125 - 43ms/epoch - 4ms/step
# Epoch 473/100000
# 10/10 - 0s - loss: 4.1445 - val_loss: 4.4504 - 42ms/epoch - 4ms/step
# Epoch 474/100000
# 10/10 - 0s - loss: 4.2846 - val_loss: 4.0129 - 40ms/epoch - 4ms/step
# Epoch 475/100000
# 10/10 - 0s - loss: 3.9684 - val_loss: 4.4451 - 41ms/epoch - 4ms/step
# Epoch 476/100000
# 10/10 - 0s - loss: 4.2235 - val_loss: 4.2467 - 41ms/epoch - 4ms/step
# Epoch 477/100000
# 10/10 - 0s - loss: 4.2295 - val_loss: 4.0054 - 38ms/epoch - 4ms/step
# Epoch 478/100000
# 10/10 - 0s - loss: 4.7263 - val_loss: 4.0237 - 40ms/epoch - 4ms/step
# Epoch 479/100000
# 10/10 - 0s - loss: 5.2012 - val_loss: 4.6391 - 40ms/epoch - 4ms/step
# Epoch 480/100000
# 10/10 - 0s - loss: 6.3009 - val_loss: 4.2437 - 45ms/epoch - 4ms/step
# Epoch 481/100000
# 10/10 - 0s - loss: 5.3563 - val_loss: 4.1188 - 44ms/epoch - 4ms/step
# Epoch 482/100000
# 10/10 - 0s - loss: 5.0261 - val_loss: 5.4661 - 45ms/epoch - 4ms/step
# Epoch 483/100000
# 10/10 - 0s - loss: 4.8501 - val_loss: 6.2598 - 41ms/epoch - 4ms/step
# Epoch 484/100000
# 10/10 - 0s - loss: 4.3955 - val_loss: 4.5373 - 40ms/epoch - 4ms/step
# Epoch 485/100000
# 10/10 - 0s - loss: 4.0246 - val_loss: 4.2456 - 69ms/epoch - 7ms/step
# Epoch 486/100000
# 10/10 - 0s - loss: 4.0714 - val_loss: 4.3905 - 41ms/epoch - 4ms/step
# Epoch 487/100000
# 10/10 - 0s - loss: 5.1262 - val_loss: 4.2501 - 40ms/epoch - 4ms/step
# Epoch 488/100000
# 10/10 - 0s - loss: 4.1803 - val_loss: 4.8881 - 41ms/epoch - 4ms/step
# Epoch 489/100000
# 10/10 - 0s - loss: 4.5821 - val_loss: 4.4411 - 41ms/epoch - 4ms/step
# Epoch 490/100000
# 10/10 - 0s - loss: 4.3592 - val_loss: 5.5091 - 42ms/epoch - 4ms/step
# Epoch 491/100000
# 10/10 - 0s - loss: 4.5366 - val_loss: 4.1851 - 41ms/epoch - 4ms/step
# Epoch 492/100000
# 10/10 - 0s - loss: 5.1930 - val_loss: 4.0911 - 41ms/epoch - 4ms/step
# Epoch 493/100000
# 10/10 - 0s - loss: 4.4833 - val_loss: 4.1475 - 40ms/epoch - 4ms/step
# Epoch 494/100000
# 10/10 - 0s - loss: 4.1226 - val_loss: 3.9937 - 40ms/epoch - 4ms/step
# Epoch 495/100000
# 10/10 - 0s - loss: 4.2555 - val_loss: 4.0268 - 40ms/epoch - 4ms/step
# Epoch 496/100000
# 10/10 - 0s - loss: 3.9865 - val_loss: 3.9986 - 42ms/epoch - 4ms/step
# Epoch 497/100000
# 10/10 - 0s - loss: 4.9257 - val_loss: 5.2780 - 40ms/epoch - 4ms/step
# Epoch 498/100000
# 10/10 - 0s - loss: 5.1068 - val_loss: 10.4157 - 40ms/epoch - 4ms/step
# Epoch 499/100000
# 10/10 - 0s - loss: 7.9864 - val_loss: 11.6850 - 39ms/epoch - 4ms/step
# Epoch 500/100000
# 10/10 - 0s - loss: 6.4790 - val_loss: 7.5520 - 39ms/epoch - 4ms/step
# Epoch 501/100000
# 10/10 - 0s - loss: 5.7892 - val_loss: 4.1261 - 41ms/epoch - 4ms/step
# Epoch 502/100000
# 10/10 - 0s - loss: 4.0201 - val_loss: 4.0407 - 42ms/epoch - 4ms/step
# Epoch 503/100000
# 10/10 - 0s - loss: 3.8620 - val_loss: 4.0413 - 39ms/epoch - 4ms/step
# Epoch 504/100000
# 10/10 - 0s - loss: 3.8922 - val_loss: 4.6715 - 41ms/epoch - 4ms/step
# Epoch 505/100000
# 10/10 - 0s - loss: 3.9443 - val_loss: 4.0091 - 41ms/epoch - 4ms/step
# Epoch 506/100000
# 10/10 - 0s - loss: 3.8700 - val_loss: 4.0577 - 42ms/epoch - 4ms/step
# Epoch 507/100000
# 10/10 - 0s - loss: 3.9125 - val_loss: 4.4292 - 41ms/epoch - 4ms/step
# Epoch 508/100000
# 10/10 - 0s - loss: 4.1484 - val_loss: 4.0470 - 41ms/epoch - 4ms/step
# Epoch 509/100000
# 10/10 - 0s - loss: 4.0583 - val_loss: 5.1069 - 40ms/epoch - 4ms/step
# Epoch 510/100000
# 10/10 - 0s - loss: 4.5056 - val_loss: 4.2329 - 41ms/epoch - 4ms/step
# Epoch 511/100000
# 10/10 - 0s - loss: 4.7177 - val_loss: 5.9821 - 42ms/epoch - 4ms/step
# Epoch 512/100000
# 10/10 - 0s - loss: 4.4858 - val_loss: 4.1896 - 41ms/epoch - 4ms/step
# Epoch 513/100000
# 10/10 - 0s - loss: 4.0830 - val_loss: 4.0417 - 43ms/epoch - 4ms/step
# Epoch 514/100000
# 10/10 - 0s - loss: 4.1148 - val_loss: 3.9903 - 42ms/epoch - 4ms/step
# Epoch 515/100000
# 10/10 - 0s - loss: 4.5669 - val_loss: 4.6428 - 39ms/epoch - 4ms/step
# Epoch 516/100000
# 10/10 - 0s - loss: 4.1383 - val_loss: 3.9983 - 42ms/epoch - 4ms/step
# Epoch 517/100000
# 10/10 - 0s - loss: 4.1706 - val_loss: 3.9975 - 41ms/epoch - 4ms/step
# Epoch 518/100000
# 10/10 - 0s - loss: 3.8870 - val_loss: 4.1667 - 41ms/epoch - 4ms/step
# Epoch 519/100000
# 10/10 - 0s - loss: 3.9272 - val_loss: 4.5728 - 40ms/epoch - 4ms/step
# Epoch 520/100000
# 10/10 - 0s - loss: 3.9956 - val_loss: 4.2832 - 40ms/epoch - 4ms/step
# Epoch 521/100000
# 10/10 - 0s - loss: 3.9579 - val_loss: 4.1543 - 40ms/epoch - 4ms/step
# Epoch 522/100000
# 10/10 - 0s - loss: 4.1282 - val_loss: 4.4053 - 40ms/epoch - 4ms/step
# Epoch 523/100000
# 10/10 - 0s - loss: 4.2401 - val_loss: 4.4309 - 40ms/epoch - 4ms/step
# Epoch 524/100000
# 10/10 - 0s - loss: 4.1122 - val_loss: 6.1189 - 42ms/epoch - 4ms/step
# Epoch 525/100000
# 10/10 - 0s - loss: 4.6651 - val_loss: 3.9925 - 42ms/epoch - 4ms/step
# Epoch 526/100000
# 10/10 - 0s - loss: 4.3989 - val_loss: 4.6121 - 42ms/epoch - 4ms/step
# Epoch 527/100000
# 10/10 - 0s - loss: 4.1376 - val_loss: 4.1586 - 40ms/epoch - 4ms/step
# Epoch 528/100000
# 10/10 - 0s - loss: 4.3175 - val_loss: 4.3987 - 41ms/epoch - 4ms/step
# Epoch 529/100000
# 10/10 - 0s - loss: 4.7257 - val_loss: 5.4561 - 41ms/epoch - 4ms/step
# Epoch 530/100000
# 10/10 - 0s - loss: 4.7957 - val_loss: 5.0535 - 39ms/epoch - 4ms/step
# Epoch 531/100000
# 10/10 - 0s - loss: 4.2760 - val_loss: 4.1950 - 43ms/epoch - 4ms/step
# Epoch 532/100000
# 10/10 - 0s - loss: 3.9422 - val_loss: 4.0155 - 39ms/epoch - 4ms/step
# Epoch 533/100000
# 10/10 - 0s - loss: 4.0892 - val_loss: 4.0277 - 43ms/epoch - 4ms/step
# Epoch 534/100000
# 10/10 - 0s - loss: 4.0556 - val_loss: 4.3686 - 40ms/epoch - 4ms/step
# Epoch 535/100000
# 10/10 - 0s - loss: 4.1312 - val_loss: 4.4579 - 40ms/epoch - 4ms/step
# Epoch 536/100000
# 10/10 - 0s - loss: 4.5771 - val_loss: 5.4858 - 41ms/epoch - 4ms/step
# Epoch 537/100000
# 10/10 - 0s - loss: 4.3247 - val_loss: 4.6040 - 41ms/epoch - 4ms/step
# Epoch 538/100000
# 10/10 - 0s - loss: 3.9661 - val_loss: 4.0377 - 40ms/epoch - 4ms/step
# Epoch 539/100000
# 10/10 - 0s - loss: 3.8815 - val_loss: 4.4186 - 42ms/epoch - 4ms/step
# Epoch 540/100000
# 10/10 - 0s - loss: 4.3979 - val_loss: 4.9894 - 40ms/epoch - 4ms/step
# Epoch 541/100000
# 10/10 - 0s - loss: 4.6262 - val_loss: 4.0460 - 41ms/epoch - 4ms/step
# Epoch 542/100000
# 10/10 - 0s - loss: 4.8246 - val_loss: 7.4148 - 39ms/epoch - 4ms/step
# Epoch 543/100000
# 10/10 - 0s - loss: 4.9744 - val_loss: 4.2950 - 42ms/epoch - 4ms/step
# Epoch 544/100000
# 10/10 - 0s - loss: 4.6432 - val_loss: 4.1584 - 40ms/epoch - 4ms/step
# Epoch 545/100000
# 10/10 - 0s - loss: 3.8206 - val_loss: 4.1855 - 41ms/epoch - 4ms/step
# Epoch 546/100000
# 10/10 - 0s - loss: 4.1323 - val_loss: 5.0469 - 40ms/epoch - 4ms/step
# Epoch 547/100000
# 10/10 - 0s - loss: 4.5350 - val_loss: 3.9770 - 41ms/epoch - 4ms/step
# Epoch 548/100000
# 10/10 - 0s - loss: 3.9456 - val_loss: 4.1231 - 39ms/epoch - 4ms/step
# Epoch 549/100000
# 10/10 - 0s - loss: 4.1866 - val_loss: 4.7500 - 40ms/epoch - 4ms/step
# Epoch 550/100000
# 10/10 - 0s - loss: 4.4075 - val_loss: 4.1312 - 39ms/epoch - 4ms/step
# Epoch 551/100000
# 10/10 - 0s - loss: 4.0629 - val_loss: 4.1044 - 38ms/epoch - 4ms/step
# Epoch 552/100000
# 10/10 - 0s - loss: 4.7635 - val_loss: 5.9065 - 41ms/epoch - 4ms/step
# Epoch 553/100000
# 10/10 - 0s - loss: 4.8924 - val_loss: 4.1617 - 42ms/epoch - 4ms/step
# Epoch 554/100000
# 10/10 - 0s - loss: 5.1931 - val_loss: 4.5362 - 40ms/epoch - 4ms/step
# Epoch 555/100000
# 10/10 - 0s - loss: 5.6765 - val_loss: 5.9090 - 39ms/epoch - 4ms/step
# Epoch 556/100000
# 10/10 - 0s - loss: 5.5346 - val_loss: 4.9456 - 40ms/epoch - 4ms/step
# ...
# Epoch 5147/100000
# 10/10 - 0s - loss: 2.8205 - val_loss: 3.0743 - 40ms/epoch - 4ms/step
# Epoch 5148/100000
# 10/10 - 0s - loss: 3.0653 - val_loss: 4.0849 - 39ms/epoch - 4ms/step
# Epoch 5149/100000
# 10/10 - 0s - loss: 2.9313 - val_loss: 3.3125 - 37ms/epoch - 4ms/step
# Epoch 5150/100000
# 10/10 - 0s - loss: 2.7169 - val_loss: 3.0859 - 47ms/epoch - 5ms/step
# Epoch 5151/100000
# 10/10 - 0s - loss: 2.6870 - val_loss: 3.2321 - 62ms/epoch - 6ms/step
# Epoch 5152/100000
# 10/10 - 0s - loss: 2.7483 - val_loss: 3.2172 - 38ms/epoch - 4ms/step
# Epoch 5153/100000
# 10/10 - 0s - loss: 2.8447 - val_loss: 3.4187 - 41ms/epoch - 4ms/step
# Epoch 5154/100000
# 10/10 - 0s - loss: 2.7894 - val_loss: 3.7410 - 40ms/epoch - 4ms/step
# Epoch 5155/100000
# 10/10 - 0s - loss: 3.2313 - val_loss: 4.4038 - 43ms/epoch - 4ms/step
# Epoch 5156/100000
# 10/10 - 0s - loss: 3.5323 - val_loss: 3.4949 - 40ms/epoch - 4ms/step
# Epoch 5157/100000
# 10/10 - 0s - loss: 3.0172 - val_loss: 3.3903 - 40ms/epoch - 4ms/step
# Epoch 5158/100000
# 10/10 - 0s - loss: 2.8219 - val_loss: 3.1333 - 42ms/epoch - 4ms/step
# Epoch 5159/100000
# 10/10 - 0s - loss: 2.7134 - val_loss: 3.2854 - 43ms/epoch - 4ms/step
# Epoch 5160/100000
# 10/10 - 0s - loss: 2.6721 - val_loss: 3.3320 - 39ms/epoch - 4ms/step
# Epoch 5161/100000
# 10/10 - 0s - loss: 2.7132 - val_loss: 3.3517 - 40ms/epoch - 4ms/step
# Epoch 5162/100000
# 10/10 - 0s - loss: 2.8335 - val_loss: 3.1506 - 37ms/epoch - 4ms/step
# Epoch 5163/100000
# 10/10 - 0s - loss: 3.0172 - val_loss: 3.3834 - 38ms/epoch - 4ms/step
# Epoch 5164/100000
# 10/10 - 0s - loss: 2.7512 - val_loss: 3.0416 - 40ms/epoch - 4ms/step
# Epoch 5165/100000
# 10/10 - 0s - loss: 2.6060 - val_loss: 3.3270 - 39ms/epoch - 4ms/step
# Epoch 5166/100000
# 10/10 - 0s - loss: 3.1485 - val_loss: 5.1611 - 38ms/epoch - 4ms/step
# Epoch 5167/100000
# 10/10 - 0s - loss: 3.5226 - val_loss: 4.9437 - 40ms/epoch - 4ms/step
# Epoch 5168/100000
# 10/10 - 0s - loss: 3.2694 - val_loss: 4.1288 - 38ms/epoch - 4ms/step
# Epoch 5169/100000
# 10/10 - 0s - loss: 3.1166 - val_loss: 3.6255 - 39ms/epoch - 4ms/step
# Epoch 5170/100000
# 10/10 - 0s - loss: 2.7478 - val_loss: 3.1664 - 40ms/epoch - 4ms/step
# Epoch 5171/100000
# 10/10 - 0s - loss: 2.5966 - val_loss: 3.1151 - 38ms/epoch - 4ms/step
# Epoch 5172/100000
# 10/10 - 0s - loss: 2.7550 - val_loss: 3.2259 - 39ms/epoch - 4ms/step
# Epoch 5173/100000
# 10/10 - 0s - loss: 2.6514 - val_loss: 3.1784 - 40ms/epoch - 4ms/step
# Epoch 5174/100000
# 10/10 - 0s - loss: 2.7949 - val_loss: 3.3848 - 45ms/epoch - 4ms/step
# Epoch 5175/100000
# 10/10 - 0s - loss: 2.6400 - val_loss: 3.1085 - 39ms/epoch - 4ms/step
# Epoch 5176/100000
# 10/10 - 0s - loss: 2.6555 - val_loss: 3.1594 - 40ms/epoch - 4ms/step
# Epoch 5177/100000
# 10/10 - 0s - loss: 2.9162 - val_loss: 3.7575 - 40ms/epoch - 4ms/step
# Epoch 5178/100000
# 10/10 - 0s - loss: 2.9619 - val_loss: 3.9753 - 41ms/epoch - 4ms/step
# Epoch 5179/100000
# 10/10 - 0s - loss: 2.8293 - val_loss: 3.1713 - 39ms/epoch - 4ms/step
# Epoch 5180/100000
# 10/10 - 0s - loss: 2.8616 - val_loss: 3.2692 - 38ms/epoch - 4ms/step
# Epoch 5181/100000
# 10/10 - 0s - loss: 2.6218 - val_loss: 3.1452 - 39ms/epoch - 4ms/step
# Epoch 5182/100000
# 10/10 - 0s - loss: 2.7031 - val_loss: 3.0965 - 41ms/epoch - 4ms/step
# Epoch 5183/100000
# 10/10 - 0s - loss: 2.6793 - val_loss: 3.3794 - 39ms/epoch - 4ms/step
# Epoch 5184/100000
# 10/10 - 0s - loss: 3.0551 - val_loss: 3.0448 - 40ms/epoch - 4ms/step
# Epoch 5185/100000
# 10/10 - 0s - loss: 2.7623 - val_loss: 3.2736 - 40ms/epoch - 4ms/step
# Epoch 5186/100000
# 10/10 - 0s - loss: 3.0731 - val_loss: 3.4582 - 39ms/epoch - 4ms/step
# Epoch 5187/100000
# 10/10 - 0s - loss: 2.7833 - val_loss: 3.1047 - 44ms/epoch - 4ms/step
# Epoch 5188/100000
# 10/10 - 0s - loss: 2.8494 - val_loss: 3.1267 - 40ms/epoch - 4ms/step
# Epoch 5189/100000
# 10/10 - 0s - loss: 2.7438 - val_loss: 3.5004 - 40ms/epoch - 4ms/step
# Epoch 5190/100000
# 10/10 - 0s - loss: 2.8401 - val_loss: 3.2069 - 66ms/epoch - 7ms/step
# Epoch 5191/100000
# 10/10 - 0s - loss: 2.7506 - val_loss: 3.1319 - 38ms/epoch - 4ms/step
# Epoch 5192/100000
# 10/10 - 0s - loss: 2.7317 - val_loss: 3.2226 - 37ms/epoch - 4ms/step
# Epoch 5193/100000
# 10/10 - 0s - loss: 3.0639 - val_loss: 3.2920 - 41ms/epoch - 4ms/step
# Epoch 5194/100000
# 10/10 - 0s - loss: 2.6727 - val_loss: 3.3127 - 40ms/epoch - 4ms/step
# Epoch 5195/100000
# 10/10 - 0s - loss: 2.7183 - val_loss: 3.3420 - 40ms/epoch - 4ms/step
# Epoch 5196/100000
# 10/10 - 0s - loss: 3.1459 - val_loss: 3.0822 - 42ms/epoch - 4ms/step
# Epoch 5197/100000
# 10/10 - 0s - loss: 2.9314 - val_loss: 3.2475 - 44ms/epoch - 4ms/step
# Epoch 5198/100000
# 10/10 - 0s - loss: 2.7178 - val_loss: 3.2030 - 53ms/epoch - 5ms/step
# Epoch 5199/100000
# 10/10 - 0s - loss: 2.7685 - val_loss: 3.1950 - 40ms/epoch - 4ms/step
# Epoch 5200/100000
# 10/10 - 0s - loss: 2.8994 - val_loss: 3.6166 - 41ms/epoch - 4ms/step
# Epoch 5201/100000
# 10/10 - 0s - loss: 3.1781 - val_loss: 3.1389 - 39ms/epoch - 4ms/step
# Epoch 5202/100000
# 10/10 - 0s - loss: 2.7765 - val_loss: 3.1800 - 38ms/epoch - 4ms/step
# Epoch 5203/100000
# 10/10 - 0s - loss: 2.6061 - val_loss: 3.2480 - 48ms/epoch - 5ms/step
# Epoch 5204/100000
# 10/10 - 0s - loss: 2.8900 - val_loss: 3.2000 - 39ms/epoch - 4ms/step
# Epoch 5205/100000
# 10/10 - 0s - loss: 2.9343 - val_loss: 3.1410 - 44ms/epoch - 4ms/step
# Epoch 5206/100000
# 10/10 - 0s - loss: 2.7435 - val_loss: 3.2105 - 38ms/epoch - 4ms/step
# Epoch 5207/100000
# 10/10 - 0s - loss: 2.7403 - val_loss: 3.0906 - 39ms/epoch - 4ms/step
# Epoch 5208/100000
# 10/10 - 0s - loss: 3.0120 - val_loss: 3.3386 - 39ms/epoch - 4ms/step
# Epoch 5209/100000
# 10/10 - 0s - loss: 3.3783 - val_loss: 4.2850 - 40ms/epoch - 4ms/step
# Epoch 5210/100000
# 10/10 - 0s - loss: 3.1575 - val_loss: 3.3051 - 39ms/epoch - 4ms/step
# Epoch 5211/100000
# 10/10 - 0s - loss: 2.8733 - val_loss: 3.8450 - 39ms/epoch - 4ms/step
# Epoch 5212/100000
# 10/10 - 0s - loss: 2.9463 - val_loss: 3.0596 - 39ms/epoch - 4ms/step
# Epoch 5213/100000
# 10/10 - 0s - loss: 2.5644 - val_loss: 3.1744 - 39ms/epoch - 4ms/step
# Epoch 5214/100000
# 10/10 - 0s - loss: 2.6107 - val_loss: 3.0488 - 39ms/epoch - 4ms/step
# Epoch 5215/100000
# 10/10 - 0s - loss: 2.6642 - val_loss: 3.4134 - 67ms/epoch - 7ms/step
# Epoch 5216/100000
# 10/10 - 0s - loss: 2.7102 - val_loss: 3.1139 - 39ms/epoch - 4ms/step
# Epoch 5217/100000
# 10/10 - 0s - loss: 2.6835 - val_loss: 3.2315 - 40ms/epoch - 4ms/step
# Epoch 5218/100000
# 10/10 - 0s - loss: 2.7909 - val_loss: 3.0936 - 40ms/epoch - 4ms/step
# Epoch 5219/100000
# 10/10 - 0s - loss: 2.7218 - val_loss: 3.1670 - 40ms/epoch - 4ms/step
# Epoch 5220/100000
# 10/10 - 0s - loss: 2.8153 - val_loss: 3.5622 - 40ms/epoch - 4ms/step
# Epoch 5221/100000
# 10/10 - 0s - loss: 2.8242 - val_loss: 3.0749 - 40ms/epoch - 4ms/step
# Epoch 5222/100000
# 10/10 - 0s - loss: 3.3273 - val_loss: 3.8804 - 38ms/epoch - 4ms/step
# Epoch 5223/100000
# 10/10 - 0s - loss: 3.3817 - val_loss: 4.3034 - 38ms/epoch - 4ms/step
# Epoch 5224/100000
# 10/10 - 0s - loss: 3.2432 - val_loss: 4.6921 - 40ms/epoch - 4ms/step
# Epoch 5225/100000
# 10/10 - 0s - loss: 3.2472 - val_loss: 3.3707 - 41ms/epoch - 4ms/step
# Epoch 5226/100000
# 10/10 - 0s - loss: 3.7065 - val_loss: 4.0168 - 40ms/epoch - 4ms/step
# Epoch 5227/100000
# 10/10 - 0s - loss: 3.6451 - val_loss: 3.9954 - 38ms/epoch - 4ms/step
# Epoch 5228/100000
# 10/10 - 0s - loss: 3.9993 - val_loss: 3.4593 - 53ms/epoch - 5ms/step
# Epoch 5229/100000
# 10/10 - 0s - loss: 3.3955 - val_loss: 3.2416 - 53ms/epoch - 5ms/step
# Epoch 5230/100000
# 10/10 - 0s - loss: 2.8079 - val_loss: 3.0498 - 39ms/epoch - 4ms/step
# Epoch 5231/100000
# 10/10 - 0s - loss: 2.5822 - val_loss: 3.7498 - 39ms/epoch - 4ms/step
# Epoch 5232/100000
# 10/10 - 0s - loss: 2.7972 - val_loss: 4.0625 - 41ms/epoch - 4ms/step
# Epoch 5233/100000
# 10/10 - 0s - loss: 2.7263 - val_loss: 3.3787 - 37ms/epoch - 4ms/step
# Epoch 5234/100000
# 10/10 - 0s - loss: 2.6276 - val_loss: 3.0947 - 40ms/epoch - 4ms/step
# Epoch 5235/100000
# 10/10 - 0s - loss: 2.7499 - val_loss: 3.0820 - 41ms/epoch - 4ms/step
# Epoch 5236/100000
# 10/10 - 0s - loss: 2.8231 - val_loss: 3.1889 - 40ms/epoch - 4ms/step
# Epoch 5237/100000
# 10/10 - 0s - loss: 2.9834 - val_loss: 4.3381 - 46ms/epoch - 5ms/step
# Epoch 5238/100000
# 10/10 - 0s - loss: 3.1549 - val_loss: 3.9190 - 43ms/epoch - 4ms/step
# Epoch 5239/100000
# 10/10 - 0s - loss: 2.8582 - val_loss: 4.8053 - 38ms/epoch - 4ms/step
# Epoch 5240/100000
# 10/10 - 0s - loss: 2.9637 - val_loss: 3.1607 - 38ms/epoch - 4ms/step
# Epoch 5241/100000
# 10/10 - 0s - loss: 2.6406 - val_loss: 3.1135 - 38ms/epoch - 4ms/step
# Epoch 5242/100000
# 10/10 - 0s - loss: 2.8035 - val_loss: 3.7092 - 39ms/epoch - 4ms/step
# Epoch 5243/100000
# 10/10 - 0s - loss: 2.9176 - val_loss: 3.2064 - 39ms/epoch - 4ms/step
# Epoch 5244/100000
# 10/10 - 0s - loss: 2.6574 - val_loss: 3.2920 - 39ms/epoch - 4ms/step
# Epoch 5245/100000
# 10/10 - 0s - loss: 2.7161 - val_loss: 3.1895 - 39ms/epoch - 4ms/step
# Epoch 5246/100000
# 10/10 - 0s - loss: 2.7087 - val_loss: 3.1155 - 39ms/epoch - 4ms/step
# Epoch 5247/100000
# 10/10 - 0s - loss: 2.6615 - val_loss: 3.2846 - 40ms/epoch - 4ms/step
# Epoch 5248/100000
# 10/10 - 0s - loss: 2.6749 - val_loss: 3.1459 - 39ms/epoch - 4ms/step
# Epoch 5249/100000
# 10/10 - 0s - loss: 2.7135 - val_loss: 3.1557 - 40ms/epoch - 4ms/step
# Epoch 5250/100000
# 10/10 - 0s - loss: 2.6579 - val_loss: 3.2446 - 39ms/epoch - 4ms/step
# Epoch 5251/100000
# 10/10 - 0s - loss: 2.6800 - val_loss: 3.2550 - 38ms/epoch - 4ms/step
# Epoch 5252/100000
# 10/10 - 0s - loss: 2.6433 - val_loss: 3.1380 - 42ms/epoch - 4ms/step
# Epoch 5253/100000
# 10/10 - 0s - loss: 2.6494 - val_loss: 3.1771 - 41ms/epoch - 4ms/step
# Epoch 5254/100000
# 10/10 - 0s - loss: 2.6825 - val_loss: 3.2544 - 40ms/epoch - 4ms/step
# Epoch 5255/100000
# 10/10 - 0s - loss: 3.3239 - val_loss: 3.8121 - 44ms/epoch - 4ms/step
# Epoch 5256/100000
# 10/10 - 0s - loss: 3.2660 - val_loss: 3.2936 - 39ms/epoch - 4ms/step
# Epoch 5257/100000
# 10/10 - 0s - loss: 3.1077 - val_loss: 3.1075 - 41ms/epoch - 4ms/step
# Epoch 5258/100000
# 10/10 - 0s - loss: 2.8013 - val_loss: 3.2375 - 40ms/epoch - 4ms/step
# Epoch 5259/100000
# 10/10 - 0s - loss: 2.6357 - val_loss: 3.7464 - 39ms/epoch - 4ms/step
# Epoch 5260/100000
# 10/10 - 0s - loss: 2.8864 - val_loss: 3.5592 - 38ms/epoch - 4ms/step
# Epoch 5261/100000
# 10/10 - 0s - loss: 2.7145 - val_loss: 3.0822 - 37ms/epoch - 4ms/step
# Epoch 5262/100000
# 10/10 - 0s - loss: 2.7339 - val_loss: 3.1139 - 44ms/epoch - 4ms/step
# Epoch 5263/100000
# 10/10 - 0s - loss: 2.7176 - val_loss: 3.0832 - 40ms/epoch - 4ms/step
# Epoch 5264/100000
# 10/10 - 0s - loss: 2.8328 - val_loss: 3.7110 - 40ms/epoch - 4ms/step
# Epoch 5265/100000
# 10/10 - 0s - loss: 3.2643 - val_loss: 3.2751 - 40ms/epoch - 4ms/step
# Epoch 5266/100000
# 10/10 - 0s - loss: 3.0040 - val_loss: 3.2285 - 52ms/epoch - 5ms/step
# Epoch 5267/100000
# 10/10 - 0s - loss: 2.8731 - val_loss: 3.1640 - 44ms/epoch - 4ms/step
# Epoch 5268/100000
# 10/10 - 0s - loss: 2.7828 - val_loss: 3.2930 - 41ms/epoch - 4ms/step
# Epoch 5269/100000
# 10/10 - 0s - loss: 2.7437 - val_loss: 3.1704 - 44ms/epoch - 4ms/step
# Epoch 5270/100000
# 10/10 - 0s - loss: 2.8522 - val_loss: 3.4926 - 50ms/epoch - 5ms/step
# Epoch 5271/100000
# 10/10 - 0s - loss: 2.7040 - val_loss: 3.1273 - 42ms/epoch - 4ms/step
# Epoch 5272/100000
# 10/10 - 0s - loss: 2.8151 - val_loss: 3.1460 - 48ms/epoch - 5ms/step
# Epoch 5273/100000
# 10/10 - 0s - loss: 2.6826 - val_loss: 3.1285 - 43ms/epoch - 4ms/step
# Epoch 5274/100000
# 10/10 - 0s - loss: 2.9557 - val_loss: 3.2501 - 46ms/epoch - 5ms/step
# Epoch 5275/100000
# 10/10 - 0s - loss: 3.2984 - val_loss: 3.1128 - 45ms/epoch - 4ms/step
# Epoch 5276/100000
# 10/10 - 0s - loss: 3.3401 - val_loss: 4.6747 - 39ms/epoch - 4ms/step
# Epoch 5277/100000
# 10/10 - 0s - loss: 2.8129 - val_loss: 3.1198 - 45ms/epoch - 4ms/step
# Epoch 5278/100000
# 10/10 - 0s - loss: 2.6728 - val_loss: 3.0502 - 40ms/epoch - 4ms/step
# Epoch 5279/100000
# 10/10 - 0s - loss: 2.9773 - val_loss: 3.1699 - 40ms/epoch - 4ms/step
# Epoch 5280/100000
# 10/10 - 0s - loss: 3.4393 - val_loss: 3.1505 - 40ms/epoch - 4ms/step
# Epoch 5281/100000
# 10/10 - 0s - loss: 2.9750 - val_loss: 3.1196 - 39ms/epoch - 4ms/step
# Epoch 5282/100000
# 10/10 - 0s - loss: 2.6658 - val_loss: 3.6293 - 39ms/epoch - 4ms/step
# Epoch 5283/100000
# 10/10 - 0s - loss: 2.7373 - val_loss: 3.5449 - 39ms/epoch - 4ms/step
# Epoch 5284/100000
# 10/10 - 0s - loss: 2.8283 - val_loss: 3.3618 - 39ms/epoch - 4ms/step
# Epoch 5285/100000
# 10/10 - 0s - loss: 2.6491 - val_loss: 3.2488 - 40ms/epoch - 4ms/step
# Epoch 5286/100000
# 10/10 - 0s - loss: 2.7000 - val_loss: 3.2798 - 39ms/epoch - 4ms/step
# Epoch 5287/100000
# 10/10 - 0s - loss: 2.6553 - val_loss: 3.0691 - 50ms/epoch - 5ms/step
# Epoch 5288/100000
# 10/10 - 0s - loss: 2.7097 - val_loss: 3.1520 - 44ms/epoch - 4ms/step
# Epoch 5289/100000
# 10/10 - 0s - loss: 2.7431 - val_loss: 3.1742 - 38ms/epoch - 4ms/step
# Epoch 5290/100000
# 10/10 - 0s - loss: 2.6155 - val_loss: 3.4256 - 41ms/epoch - 4ms/step
# Epoch 5291/100000
# 10/10 - 0s - loss: 2.7784 - val_loss: 3.2442 - 40ms/epoch - 4ms/step
# Epoch 5292/100000
# 10/10 - 0s - loss: 2.7461 - val_loss: 3.2676 - 39ms/epoch - 4ms/step
# Epoch 5293/100000
# 10/10 - 0s - loss: 2.7766 - val_loss: 3.0810 - 39ms/epoch - 4ms/step
# Epoch 5294/100000
# 10/10 - 0s - loss: 2.9121 - val_loss: 3.3687 - 39ms/epoch - 4ms/step
# Epoch 5295/100000
# 10/10 - 0s - loss: 2.7448 - val_loss: 3.3419 - 39ms/epoch - 4ms/step
# Epoch 5296/100000
# 10/10 - 0s - loss: 2.7091 - val_loss: 3.3099 - 38ms/epoch - 4ms/step
# Epoch 5297/100000
# 10/10 - 0s - loss: 2.6844 - val_loss: 4.1649 - 45ms/epoch - 4ms/step
# Epoch 5298/100000
# 10/10 - 0s - loss: 2.8848 - val_loss: 3.1636 - 38ms/epoch - 4ms/step
# Epoch 5299/100000
# 10/10 - 0s - loss: 2.6282 - val_loss: 3.0549 - 39ms/epoch - 4ms/step
# Epoch 5300/100000
# 10/10 - 0s - loss: 2.6105 - val_loss: 3.1615 - 39ms/epoch - 4ms/step
# Epoch 5301/100000
# 10/10 - 0s - loss: 2.7113 - val_loss: 3.2994 - 40ms/epoch - 4ms/step
# Epoch 5302/100000
# 10/10 - 0s - loss: 2.7830 - val_loss: 3.3507 - 38ms/epoch - 4ms/step
# Epoch 5303/100000
# 10/10 - 0s - loss: 2.7961 - val_loss: 3.2743 - 39ms/epoch - 4ms/step
# Epoch 5304/100000
# 10/10 - 0s - loss: 2.7054 - val_loss: 3.1420 - 39ms/epoch - 4ms/step
# Epoch 5305/100000
# 10/10 - 0s - loss: 2.6105 - val_loss: 3.0701 - 42ms/epoch - 4ms/step
# Epoch 5306/100000
# 10/10 - 0s - loss: 2.9079 - val_loss: 3.2883 - 40ms/epoch - 4ms/step
# Epoch 5307/100000
# 10/10 - 0s - loss: 3.0633 - val_loss: 4.0633 - 39ms/epoch - 4ms/step
# Epoch 5308/100000
# 10/10 - 0s - loss: 2.9466 - val_loss: 3.9234 - 38ms/epoch - 4ms/step
# Epoch 5309/100000
# 10/10 - 0s - loss: 2.9661 - val_loss: 3.2923 - 50ms/epoch - 5ms/step
# Epoch 5310/100000
# 10/10 - 0s - loss: 2.6985 - val_loss: 3.1650 - 46ms/epoch - 5ms/step
# Epoch 5311/100000
# 10/10 - 0s - loss: 2.8969 - val_loss: 3.0511 - 43ms/epoch - 4ms/step
# Epoch 5312/100000
# 10/10 - 0s - loss: 2.8555 - val_loss: 3.1981 - 45ms/epoch - 5ms/step
# Epoch 5313/100000
# 10/10 - 0s - loss: 2.8651 - val_loss: 3.1228 - 47ms/epoch - 5ms/step
# Epoch 5314/100000
# 10/10 - 0s - loss: 2.7197 - val_loss: 3.0683 - 41ms/epoch - 4ms/step
# Epoch 5315/100000
# 10/10 - 0s - loss: 2.7656 - val_loss: 3.1800 - 40ms/epoch - 4ms/step
# Epoch 5316/100000
# 10/10 - 0s - loss: 2.9227 - val_loss: 3.8297 - 40ms/epoch - 4ms/step
# Epoch 5317/100000
# 10/10 - 0s - loss: 3.0314 - val_loss: 3.1337 - 42ms/epoch - 4ms/step
# Epoch 5318/100000
# 10/10 - 0s - loss: 2.6297 - val_loss: 3.2008 - 41ms/epoch - 4ms/step
# Epoch 5319/100000
# 10/10 - 0s - loss: 2.5988 - val_loss: 3.1774 - 39ms/epoch - 4ms/step
# Epoch 5320/100000
# 10/10 - 0s - loss: 2.7171 - val_loss: 3.0987 - 38ms/epoch - 4ms/step
# Epoch 5321/100000
# 10/10 - 0s - loss: 2.6667 - val_loss: 3.0789 - 37ms/epoch - 4ms/step
# Epoch 5322/100000
# 10/10 - 0s - loss: 2.6649 - val_loss: 3.0815 - 39ms/epoch - 4ms/step
# Epoch 5323/100000
# 10/10 - 0s - loss: 2.5825 - val_loss: 3.1083 - 39ms/epoch - 4ms/step
# Epoch 5324/100000
# 10/10 - 0s - loss: 2.8533 - val_loss: 3.5018 - 44ms/epoch - 4ms/step
# Epoch 5325/100000
# 10/10 - 0s - loss: 2.6923 - val_loss: 3.1075 - 39ms/epoch - 4ms/step
# Epoch 5326/100000
# 10/10 - 0s - loss: 2.6545 - val_loss: 3.1711 - 38ms/epoch - 4ms/step
# Epoch 5327/100000
# 10/10 - 0s - loss: 2.6494 - val_loss: 3.0840 - 41ms/epoch - 4ms/step
# Epoch 5328/100000
# 10/10 - 0s - loss: 2.5824 - val_loss: 3.1656 - 40ms/epoch - 4ms/step
# Epoch 5329/100000
# 10/10 - 0s - loss: 2.8285 - val_loss: 3.0877 - 39ms/epoch - 4ms/step
# Epoch 5329: early stopping

# %%
# define filename for saving the model and history
filepath = 'models/dnn_noct_' + user_input

# Save a model using the HDF5 format
saving_model(model, filepath+'.h5')

# Save history
saving_history(history, filepath)

# %%
# Load a model from the HDF5 format
model = loading_model(filepath + ".h5")
model.summary()

# Load history
history_dict = loading_history(filepath)
# Out:
# Model: "sequential_32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_115 (Dense)           (None, 64)                320
#
#  dense_116 (Dense)           (None, 16)                1040
#
#  dense_117 (Dense)           (None, 4)                 68
#
#  dense_118 (Dense)           (None, 1)                 5
#
# =================================================================
# Total params: 1,433
# Trainable params: 1,433
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Calculate predictions
predictions = calculate_predictions(model)

# define filepath for plots
filepath = 'plots/dnn_noct_' + user_input

# Plot training history 
plot_training(history_dict, filepath + "_training")

# Plot actual vs prediction for training set
actual_prediction_plot(y_train, predictions['train'], 'Training Set', filepath+"_train")

# Plot actual vs prediction for validation set
actual_prediction_plot(y_test, predictions['test'], 'Test Set', filepath+"_test")
# Out:
# 32/32 [==============================] - 0s 884us/step
# 11/11 [==============================] - 0s 1ms/step

# %%
# Compute score values for training set
# Note that this returns a list of scores.The first index is r_quare and the second index is mse
scores_train = compute_metrics(y_train, predictions['train'])
r_square_train = scores_train[0]
mse_train = scores_train[1]

# Compute score values for training set
scores_test = compute_metrics(y_test, predictions['test'])
r_square_test = scores_test[0]
mse_test = scores_test[1]

# Estimate NOCT
noct = compute_noct(model)
# Out:
# 1/1 [==============================] - 0s 51ms/step

# %%
# Print the results
print("NOCT = {:.2f}".format( noct ))
print("R_SQUARE Train = {:.2f}".format( r_square_train ))
print("MSE Train = {:.2f}".format( mse_train ))
print("R_SQUARE Test = {:.2f}".format( r_square_test ))
print("MSE Test = {:.2f}".format( mse_test ))
# Out:
# NOCT = 50.84
# R_SQUARE Train = 0.84
# MSE Train = 2.55
# R_SQUARE Test = 0.82
# MSE Test = 3.09

# %%
'''
# Plot training history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
'''
# Out:
# "\n# Plot training history\nplt.plot(history.history['loss'], label='train')\nplt.plot(history.history['val_loss'], label='test')\nplt.legend()\nplt.show()\n"

# %%
'''
# Plot actual vs prediction for training set
plt.plot(y_train,PredTestSet,'ro')
plt.title('Training Set')
plt.xlabel('Actual')
plt.ylabel('Predicted')

# Compute R-Square value for training set
TestR2Value = metrics.r2_score(y_train,PredTestSet)
print("Training Set R-Square=", TestR2Value)
'''
# Out:
# '\n# Plot actual vs prediction for training set\nplt.plot(y_train,PredTestSet,\'ro\')\nplt.title(\'Training Set\')\nplt.xlabel(\'Actual\')\nplt.ylabel(\'Predicted\')\n\n# Compute R-Square value for training set\nTestR2Value = metrics.r2_score(y_train,PredTestSet)\nprint("Training Set R-Square=", TestR2Value)\n'

# %%
'''
# Plot actual vs prediction for validation set
plt.plot(y_test,PredValSet,'ro')
plt.title('Test Set')
plt.xlabel('Actual')
plt.ylabel('Predicted')

# Compute R-Square value for validation set
ValR2Value = metrics.r2_score(y_test,PredValSet)
print("Test Set R-Square=",ValR2Value)
'''
# Out:
# '\n# Plot actual vs prediction for validation set\nplt.plot(y_test,PredValSet,\'ro\')\nplt.title(\'Test Set\')\nplt.xlabel(\'Actual\')\nplt.ylabel(\'Predicted\')\n\n# Compute R-Square value for validation set\nValR2Value = metrics.r2_score(y_test,PredValSet)\nprint("Test Set R-Square=",ValR2Value)\n'

# %%
#X_test

# %%
'''
x = pd.DataFrame(columns=['irradiance', 'wind_speed', 'wind_direction', 'ambient_temperature'])
x.loc[0] = [800,1,120,20]
x = np.asarray(x)
x=tf.convert_to_tensor(x, dtype=tf.int32)
display(x)
#display(X_test.head(2))
y_pred = model.predict(x)
noct = float("{:.2f}".format( y_pred[0][0] ))
#print("NOCT = {:.2f}".format( noct ))
'''
# Out:
# '\nx = pd.DataFrame(columns=[\'irradiance\', \'wind_speed\', \'wind_direction\', \'ambient_temperature\'])\nx.loc[0] = [800,1,120,20]\nx = np.asarray(x)\nx=tf.convert_to_tensor(x, dtype=tf.int32)\ndisplay(x)\n#display(X_test.head(2))\ny_pred = model.predict(x)\nnoct = float("{:.2f}".format( y_pred[0][0] ))\n#print("NOCT = {:.2f}".format( noct ))\n'

# %%
'''
# Load a model from the HDF5 format
loaded_h5_model = loading_model("dnn_noct.h5")
loaded_h5_model.summary()
'''
# Out:
# '\n# Load a model from the HDF5 format\nloaded_h5_model = loading_model("dnn_noct.h5")\nloaded_h5_model.summary()\n'
